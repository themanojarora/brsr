# %%
import pandas as pd
from pathlib import Path
from typing import List, Dict, Any

# %%
class ConsumerComplaintsExtractor:
    def __init__(self):
        self.ELEMENT_NAME_COL = 'Element Name'
        self.UNIT_COL = 'Unit'
        self.VALUE_COL = 'Fact Value'
        self.COMPANY_NAME_ELEMENT = 'NameOfTheCompany'

        self.METRIC_MAP = {
            'ConsumerComplaintsReceivedDuringTheYear': 'Received',
            'ConsumerComplaintsPendingResolutionAtEndOfYear': 'Pending'
        }

    def _get_company_name(self, df: pd.DataFrame) -> str:
        row = df[df[self.ELEMENT_NAME_COL] == self.COMPANY_NAME_ELEMENT]
        if not row.empty:
            return str(row.iloc[0][self.VALUE_COL]).strip()
        return "Unknown Company"

    def _extract_category_and_year(self, unit: str) -> (str, str):
        parts = unit.split('_')
        if len(parts) >= 2:
            category = parts[1].replace("TradePractices", "Trade Practices").replace("Of", " of ")
            year_type = 'PY' if unit.endswith('_PY') else 'FY'
            return category, year_type
        return "Unknown", "FY"

    def _process_single_file(self, file_path: Path) -> List[Dict[str, Any]]:
        try:
            df = pd.read_excel(file_path, engine='openpyxl')
        except Exception as e:
            print(f"Error reading {file_path.name}: {e}")
            return []

        company_name = self._get_company_name(df)
        print(f"\nProcessing: {company_name} ({file_path.name})")

        results = []

        for metric_field, metric_label in self.METRIC_MAP.items():
            subset = df[df[self.ELEMENT_NAME_COL] == metric_field]

            print(f"  - Found {len(subset)} rows for '{metric_field}'")

            for _, row in subset.iterrows():
                unit = str(row[self.UNIT_COL])
                category, year_type = self._extract_category_and_year(unit)

                try:
                    value = pd.to_numeric(str(row[self.VALUE_COL]).strip(), errors='coerce')
                    if pd.isna(value):
                        continue
                    results.append({
                        'Company Name': company_name,
                        'Complaint Category': category,
                        'Metric Type': metric_label,
                        'Year Type': year_type,
                        'Value': int(value)
                    })
                except Exception as e:
                    print(f"    Skipping invalid row: {unit}, value={row[self.VALUE_COL]} ({e})")
        print(f"  → Extracted {len(results)} complaint records.")
        return results

    def process_directory(self, directory: str) -> pd.DataFrame:
        all_data: List[Dict[str, Any]] = []
        dir_path = Path(directory)

        if not dir_path.exists():
            print(f"Directory '{directory}' not found.")
            return pd.DataFrame()

        for file in dir_path.iterdir():
            if file.suffix.lower() in ['.xlsx', '.xls']:
                rows = self._process_single_file(file)
                all_data.extend(rows)

        return pd.DataFrame(all_data)

    def export_to_excel(self, df: pd.DataFrame, output_file: str):
        if df.empty:
            print("DataFrame is empty. No export.")
            return
        try:
            df.to_excel(output_file, index=False)
            print(f"\n✅ Exported to '{output_file}' successfully.")
        except Exception as e:
            print(f"Failed to export: {e}")

# %%
extractor = ConsumerComplaintsExtractor()
df = extractor.process_directory("excel_files")
extractor.export_to_excel(df, "p9_consumer_complaints.xlsx")
# Out:
# Processing: 360 One Wam Limited (360_ONE_WAM_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 3I Infotech Limited (3I_Infotech_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 3M India Limited (3M_INDIA_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing:
India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yasho Industries Limited (Yasho_Industries_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yatharth Hospital & Trauma Care Services Limited (YATHARTH_HOSPITAL_&_TRAUMA_CARE_SERVICES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yatra Online Limited (Yatra_Online_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yes Bank Limited (Yes_Bank_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zaggle Prepaid Ocean Services Limited (Zaggle_Prepaid_Ocean_Services_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zee Entertainment Enterprises Limited (Zee_Entertainment_Enterprises_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zee Media Corporation Limited (Zee_Media_Corporation_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zensar Technologies Limited (ZENSAR_TECHNOLOGIES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zen Technologies Limited (Zen_Technologies_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: ZF Commercial Vehicle Control Systems India Limited (ZF_Commercial_Vehicle_Control_Systems_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zomato Limited (Zomato_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zota Health Care Limited (ZOTA_HEALTH_CARE_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zydus Lifesciences Limited (Zydus_Lifesciences_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zydus Wellness Limited (Zydus_Wellness_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# ✅ Exported to 'p9_cconsumer_omplaints.xlsx' successfully.

# %%
bb

# %%
from pathlib import Path
import pandas as pd

# Assuming you've already defined and imported the class
extractor = ConsumerComplaintsExtractor()

# Set your data directory
directory = "excel_files"  # Update this

# Process all files and extract the full complaint dataset
df = extractor.process_directory(directory)

if df.empty:
    print("No complaint data extracted.")
else:
    # Group by company and calculate total complaints (across all categories, years, metrics)
    summary = (
        df.groupby("Company Name")["Value"]
        .sum()
        .reset_index()
        .sort_values(by="Value", ascending=False)
        .head(10)
    )

    print("\n🔝 Top 10 companies by total consumer complaints:\n")
    print(summary.to_string(index=False))
# Out:
# Processing: 360 One Wam Limited (360_ONE_WAM_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 3I Infotech Limited (3I_Infotech_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 3M India Limited (3M_INDIA_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 5paisa Capital Limited (5paisa_Capital_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: 63 Moons Technologies Limited (63_moons_technologies_limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aarti Drugs Limited (Aarti_Drugs_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aarti Industries Limited (Aarti_Industries_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aarti Pharmalabs Limited (Aarti_Pharmalabs_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aavas Financiers Limited (Aavas_Financiers_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Abans Holdings Limited (ABANS_HOLDINGS_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: ABB India Limited (ABB_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Accelya Solutions India Limited (Accelya_Solutions_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: ACC Limited (ACC_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Action Construction Equipment Limited (Action_Construction_Equipment_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Energy Solutions Limited (Adani_Energy_Solutions_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Enterprises Limited (Adani_Enterprises_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Green Energy Limited (Adani_Green_Energy_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Ports and Special Economic Zone Limited (Adani_Ports_and_Special_Economic_Zone_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Power Limited (ADANI_POWER_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Total Gas Limited (Adani_Total_Gas_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Adani Wilmar Limited (ADANI_WILMAR_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: ADF Foods Limited (ADF_Foods_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aditya Birla Capital Limited (Aditya_Birla_Capital_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aditya Birla Fashion and Retail Limited (Aditya_Birla_Fashion_and_Retail_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aditya Birla Sun Life AMC Limited (Aditya_Birla_Sun_Life_AMC_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Ador Welding Limited (Ador_Welding_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Advanced Enzyme Technologies Limited (Advanced_Enzyme_Technologies_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aegis Logistics Limited (Aegis_Logistics_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Aether Industries Limited (Aether_Industries_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Affle (India) Limited (Affle_(India)_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Agarwal Industrial Corporation Limited (Agarwal_Industrial_Corporation_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: AGI Greenpac Limited (AGI_Greenpac_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Agro Tech Foods Limited (Agro_Tech_Foods_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Ags Transact Technologies Limited (AGS_TRANSACT_TECHNOLOGIES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing:
_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Veranda Learning Solutions Limited (VERANDA_LEARNING_SOLUTIONS_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vesuvius India Limited (Vesuvius_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vidhi Specialty Food Ingredients Limited (VIDHI_SPECIALTY_FOOD_INGREDIENTS_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vijaya Diagnostic Centre Limited (Vijaya_Diagnostic_Centre_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vinati Organics Limited (Vinati_Organics_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vindhya Telelinks Limited (Vindhya_Telelinks_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vip Industries Limited (VIP_INDUSTRIES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Visaka Industries Limited (Visaka_Industries_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vishnu Chemicals Limited (Vishnu_Chemicals_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vishnu Prakash R Punglia Limited (VISHNU_PRAKASH_R_PUNGLIA_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vodafone Idea Limited (Vodafone_Idea_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Voltamp Transformers Limited (Voltamp_Transformers_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Voltas Limited (Voltas_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vrl Logistics Limited (VRL_LOGISTICS_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Vst Industries Limited (VST_INDUSTRIES_LIMITED.xlsx)
#   - Found 42 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 42 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 84 complaint records.
#
# Processing: Websol Energy System Limited (WEBSOL_ENERGY_SYSTEM_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Welspun Corp Limited (Welspun_Corp_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Welspun Enterprises Limited (Welspun_Enterprises_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Welspun Living Limited (Welspun_Living_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Wendt (India) Limited (Wendt_(India)_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Westlife Foodworld Limited (Westlife_Foodworld_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: West Coast Paper Mills Limited (West_Coast_Paper_Mills_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Wheels India Limited (Wheels_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Whirlpool of India Limited (Whirlpool_of_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Wipro Limited (Wipro_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Wockhardt Limited (Wockhardt_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Wonderla Holidays Limited (Wonderla_Holidays_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Xchanging Solutions Limited (Xchanging_Solutions_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Xpro India Limited (Xpro_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yasho Industries Limited (Yasho_Industries_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yatharth Hospital & Trauma Care Services Limited (YATHARTH_HOSPITAL_&_TRAUMA_CARE_SERVICES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yatra Online Limited (Yatra_Online_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Yes Bank Limited (Yes_Bank_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zaggle Prepaid Ocean Services Limited (Zaggle_Prepaid_Ocean_Services_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zee Entertainment Enterprises Limited (Zee_Entertainment_Enterprises_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zee Media Corporation Limited (Zee_Media_Corporation_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zensar Technologies Limited (ZENSAR_TECHNOLOGIES_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zen Technologies Limited (Zen_Technologies_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: ZF Commercial Vehicle Control Systems India Limited (ZF_Commercial_Vehicle_Control_Systems_India_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zomato Limited (Zomato_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zota Health Care Limited (ZOTA_HEALTH_CARE_LIMITED.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zydus Lifesciences Limited (Zydus_Lifesciences_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# Processing: Zydus Wellness Limited (Zydus_Wellness_Limited.xlsx)
#   - Found 14 rows for 'ConsumerComplaintsReceivedDuringTheYear'
#   - Found 14 rows for 'ConsumerComplaintsPendingResolutionAtEndOfYear'
#   → Extracted 28 complaint records.
#
# 🔝 Top 10 companies by total consumer complaints:
#
#                                  Company Name    Value
#                         Dish TV India Limited 21003834
#                           State Bank Of India  7363180
# Crompton Greaves Consumer Electricals Limited  5362703
#                       Orient Electric Limited  3455632
#               Reliance Infrastructure Limited  3110372
#                             Blue Star Limited  2739783
#                          Punjab National Bank  2730702
#                          TTK Prestige Limited  2650001
#                                Bank of Baroda  2062891
#                          Indian Overseas Bank  1703459
