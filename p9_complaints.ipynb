# %%
import pandas as pd
import os
import re
from pathlib import Path
from typing import Dict, List, Optional, Any

# %%
# Fields to extract
ELEMENT_NAME_COL = 'Element Name'
VALUE_COL = 'Fact Value'
COMPANY_NAME_ELEMENT = 'NameOfTheCompany'
COMPLAINT_MECHANISM_ELEMENT = 'DescribeTheMechanismsInPlaceToReceiveAndRespondToConsumerComplaintsAndFeedbackExplanatoryTextBlock'

# %%
def get_text_value(df: pd.DataFrame, element_name: str) -> Optional[str]:
    if ELEMENT_NAME_COL not in df.columns or VALUE_COL not in df.columns:
        return None
    series = df.loc[df[ELEMENT_NAME_COL] == element_name, VALUE_COL]
    return str(series.iloc[0]) if not series.empty else None


def check_complaint_mechanisms_from_all_text(df: pd.DataFrame) -> Dict[str, int]:
    mechanism_flags = {mechanism: 0 for mechanism in MECHANISM_KEYWORDS.keys()}
    text_columns = df.select_dtypes(include='object')
    full_text = ' '.join(text_columns.fillna('').astype(str).values.flatten())

    for mechanism, pattern in PRECOMPILED_MECHANISM_REGEX.items():
        if pattern.search(full_text):
            mechanism_flags[mechanism] = 1
    return mechanism_flags


def extract_phone_numbers(text: Optional[str]) -> Optional[str]:
    if not text:
        return None
    numbers = PHONE_REGEX.findall(text)
    if numbers:
        cleaned_numbers = [num.strip() for num in numbers]
        unique_numbers = list(dict.fromkeys(cleaned_numbers))
        return ", ".join(unique_numbers)
    return None


def extract_consumer_complaint_info(directory: str, output_file: str) -> None:
    source_path = Path(directory)
    summary_data: List[Dict[str, Any]] = []

    if not source_path.is_dir() or not any(source_path.iterdir()):
        print(f"Error: The directory '{directory}' is empty or does not exist.")
        return

    print(f"[INFO] Starting analysis of files in '{directory}'...\n")

    for file_path in source_path.iterdir():
        if file_path.is_dir() or file_path.suffix not in ['.xlsx', '.xls', '.csv']:
            continue

        print(f"--- Processing File: {file_path.name} ---")

        try:
            if file_path.suffix in ['.xlsx', '.xls']:
                df = pd.read_excel(file_path, engine='openpyxl')
            else:
                df = pd.read_csv(file_path, on_bad_lines='skip', encoding_errors='ignore')

            company_name = get_text_value(df, COMPANY_NAME_ELEMENT) or "Company Name Not Found"
            complaint_text = get_text_value(df, COMPLAINT_MECHANISM_ELEMENT)

            mechanism_flags = check_complaint_mechanisms_from_all_text(df)
            extracted_phone = extract_phone_numbers(complaint_text)

            data_entry = {
                'Company Name': company_name,
                'Extracted Phone Number': extracted_phone,
                'Consumer Complaint Mechanism Text': complaint_text or "Mechanism Text Not Found"
            }

            data_entry.update(mechanism_flags)
            summary_data.append(data_entry)

            print(f"  Successfully extracted data for: {company_name}")
            if extracted_phone:
                print(f"  Extracted Phone: {extracted_phone}")

        except Exception as e:
            print(f"An error occurred while processing file {file_path.name}: {e}\n")

    if not summary_data:
        print("\nNo valid data could be processed from the files.")
        return

    summary_df = pd.DataFrame(summary_data)

    column_order = ['Company Name'] + list(MECHANISM_KEYWORDS.keys()) + ['Extracted Phone Number', 'Consumer Complaint Mechanism Text']
    summary_df = summary_df.reindex(columns=column_order)

    try:
        summary_df.to_excel(output_file, index=False, engine='openpyxl')

        print(f"\nSUCCESS: Master Excel sheet '{output_file}' has been created.")
        print(f"Total companies processed: {len(summary_df)}")

        print("\n--- SUMMARY STATISTICS (Top 5) ---")
        for mechanism in list(MECHANISM_KEYWORDS.keys())[:5]:
            count = summary_df[mechanism].sum()
            percentage = (count / len(summary_df)) * 100 if len(summary_df) > 0 else 0
            print(f"{mechanism}: {count} companies ({percentage:.1f}%)")
        print("...")

        print("\nFirst few rows of the consolidated data:")
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 120)
        pd.set_option('display.max_colwidth', 40)
        print(summary_df.head())

    except Exception as e:
        print(f"\nERROR: Could not save the Excel file '{output_file}'. Reason: {e}")

# %%
MECHANISM_KEYWORDS: Dict[str, List[str]] = {
    'In-Person / Branch Visit': ['in-person', 'branch visit', 'visit branch', 'physical visit', 'walk-in', 'office visit'],
    'Postal Mail': ['postal mail', 'post', 'letter'],
    'Written Correspondence': ['written correspondence', 'written complaint', 'grievance in writing', 'in writing'],
    'Social Media': ['social media', 'facebook', 'twitter', 'instagram', 'linkedin', 'whatsapp', 'telegram'],
    'Designated Grievance Officer / Nodal Team': ['grievance officer', 'nodal team', 'grievance cell', 'complaint officer', 'nodal officer'],
    'Website / Online Portal': ['website', 'online portal', 'web portal', 'online platform', 'internet', 'web-based'],
    'Phone / Toll-Free Helpline': ['phone', 'toll-free', 'helpline', 'telephone', 'call', 'hotline', 'customer care number'],
    'Email Communication': ['email', 'e-mail', 'electronic mail', 'email communication'],
    'Mobile App': ['mobile app', 'app store', 'play store', 'in-app', 'application'],
    'Chatbot / Live Chat': ['chatbot', 'live chat', 'web chat', 'chat bot', 'virtual assistant'],
    'Ombudsman / Regulatory Body': ['ombudsman', 'regulatory body', 'regulator', 'appellate authority'],
    'Fax': ['fax', 'facsimile'],
}

PRECOMPILED_MECHANISM_REGEX = {
    mechanism: re.compile('|'.join(r'\b' + re.escape(keyword) + r'\b' for keyword in keywords), re.IGNORECASE)
    for mechanism, keywords in MECHANISM_KEYWORDS.items()
}

PHONE_REGEX = re.compile(r"""
    (?:(?:\+91|0)?(?:[-\s]?)?)?      # Optional country code
    (?:(?:\(\d{2,5}\))?[-\s]?)?      # Optional STD code
    (?:(?:\d[-\s]?){7,12}\d)         # Digits with optional dashes/spaces
""", re.VERBOSE)

# %%
source_directory = 'excel_files'
output_excel_file = 'p9_complaints.xlsx'

if not os.path.exists(source_directory):
    os.makedirs(source_directory)
    print(f"Created directory: {source_directory}")
    print("Please add your company Excel/CSV files to this directory before running again.")

extract_consumer_complaint_info(source_directory, output_excel_file)
# Out:
# [INFO] Starting analysis of files in 'excel_files'...
#
# --- Processing File: 360_ONE_WAM_LIMITED.xlsx ---
#   Successfully extracted data for: 360 One Wam Limited
# --- Processing File: 3I_Infotech_Limited.xlsx ---
#   Successfully extracted data for: 3I Infotech Limited
# --- Processing File: 3M_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: 3M India Limited
# --- Processing File: 5paisa_Capital_Limited.xlsx ---
#   Successfully extracted data for: 5paisa Capital Limited
# --- Processing File: 63_moons_technologies_limited.xlsx ---
#   Successfully extracted data for: 63 Moons Technologies Limited
# --- Processing File: Aarti_Drugs_Limited.xlsx ---
#   Successfully extracted data for: Aarti Drugs Limited
# --- Processing File: Aarti_Industries_Limited.xlsx ---
#   Successfully extracted data for: Aarti Industries Limited
# --- Processing File: Aarti_Pharmalabs_Limited.xlsx ---
#   Successfully extracted data for: Aarti Pharmalabs Limited
# --- Processing File: Aavas_Financiers_Limited.xlsx ---
#   Successfully extracted data for: Aavas Financiers Limited
# --- Processing File: ABANS_HOLDINGS_LIMITED.xlsx ---
#   Successfully extracted data for: Abans Holdings Limited
# --- Processing File: ABB_India_Limited.xlsx ---
#   Successfully extracted data for: ABB India Limited
# --- Processing File: Accelya_Solutions_India_Limited.xlsx ---
#   Successfully extracted data for: Accelya Solutions India Limited
# --- Processing File: ACC_Limited.xlsx ---
#   Successfully extracted data for: ACC Limited
# --- Processing File: Action_Construction_Equipment_Limited.xlsx ---
#   Successfully extracted data for: Action Construction Equipment Limited
# --- Processing File: Adani_Energy_Solutions_Limited.xlsx ---
#   Successfully extracted data for: Adani Energy Solutions Limited
# --- Processing File: Adani_Enterprises_Limited.xlsx ---
#   Successfully extracted data for: Adani Enterprises Limited
# --- Processing File: Adani_Green_Energy_Limited.xlsx ---
#   Successfully extracted data for: Adani Green Energy Limited
# --- Processing File: Adani_Ports_and_Special_Economic_Zone_Limited.xlsx ---
#   Successfully extracted data for: Adani Ports and Special Economic Zone Limited
# --- Processing File: ADANI_POWER_LIMITED.xlsx ---
#   Successfully extracted data for: Adani Power Limited
# --- Processing File: Adani_Total_Gas_Limited.xlsx ---
#   Successfully extracted data for: Adani Total Gas Limited
# --- Processing File: ADANI_WILMAR_LIMITED.xlsx ---
#   Successfully extracted data for: Adani Wilmar Limited
# --- Processing File: ADF_Foods_Limited.xlsx ---
#   Successfully extracted data for: ADF Foods Limited
# --- Processing File: Aditya_Birla_Capital_Limited.xlsx ---
#   Successfully extracted data for: Aditya Birla Capital Limited
#   Extracted Phone: 1800-270-7000, -1-800-270-7000
# --- Processing File: Aditya_Birla_Fashion_and_Retail_Limited.xlsx ---
#   Successfully extracted data for: Aditya Birla Fashion and Retail Limited
# --- Processing File: Aditya_Birla_Sun_Life_AMC_Limited.xlsx ---
#   Successfully extracted data for: Aditya Birla Sun Life AMC Limited
# --- Processing File: Ador_Welding_Limited.xlsx ---
#   Successfully extracted data for: Ador Welding Limited
# --- Processing File: Advanced_Enzyme_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Advanced Enzyme Technologies Limited
# --- Processing File: Aegis_Logistics_Limited.xlsx ---
#   Successfully extracted data for: Aegis Logistics Limited
# --- Processing File: Aether_Industries_Limited.xlsx ---
#   Successfully extracted data for: Aether Industries Limited
# --- Processing File: Affle_(India)_Limited.xlsx ---
#   Successfully extracted data for: Affle (India) Limited
# --- Processing File: Agarwal_Industrial_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Agarwal Industrial Corporation Limited
# --- Processing File: AGI_Greenpac_Limited.xlsx ---
#   Successfully extracted data for: AGI Greenpac Limited
# --- Processing File: Agro_Tech_Foods_Limited.xlsx ---
#   Successfully extracted data for: Agro Tech Foods Limited
# --- Processing File: AGS_TRANSACT_TECHNOLOGIES_LIMITED.xlsx ---
#   Successfully extracted data for: Ags Transact Technologies Limited
# --- Processing File: Ahluwalia_Contracts_(India)_Limited.xlsx ---
#   Successfully extracted data for: Ahluwalia Contracts (India) Limited
# --- Processing File: AIA_Engineering_Limited.xlsx ---
#   Successfully extracted data for: AIA Engineering Limited
# --- Processing File: Ajanta_Pharma_Limited.xlsx ---
#   Successfully extracted data for: Ajanta Pharma Limited
# --- Processing File: AJMERA_REALTY_&_INFRA_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Ajmera Realty & Infra India Limited
# --- Processing File: Akzo_Nobel_India_Limited.xlsx ---
#   Successfully extracted data for: Akzo Nobel India Limited
#   Extracted Phone: 1800 3000 4455
# --- Processing File: Alembic_Limited.xlsx ---
#   Successfully extracted data for: Alembic Limited
# --- Processing File: ALEMBIC_PHARMACEUTICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Alembic Pharmaceuticals Limited
# --- Processing File: Alicon_Castalloy_Limited.xlsx ---
#   Successfully extracted data for: Alicon Castalloy Limited
# --- Processing File: Alkem_Laboratories_Limited.xlsx ---
#   Successfully extracted data for: Alkem Laboratories Limited
# --- Processing File: ALKYL_AMINES_CHEMICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Alkyl Amines Chemicals Limited
# --- Processing File: Allcargo_Gati_Limited.xlsx ---
#   Successfully extracted data for: Allcargo Gati Limited
# --- Processing File: Allcargo_Logistics_Limited.xlsx ---
#   Successfully extracted data for: Allcargo Logistics Limited
# --- Processing File: ALLSEC_TECHNOLOGIES_LIMITED.xlsx ---
#   Successfully extracted data for: Allsec Technologies Limited
# --- Processing File: ALOK_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Alok Industries Limited
# --- Processing File: Amber_Enterprises_India_Limited.xlsx ---
#   Successfully extracted data for: Amber Enterprises India Limited
# --- Processing File: AMBIKA_COTTON_MILLS_LIMITED.xlsx ---
#   Successfully extracted data for: Ambika Cotton Mills Limited
# --- Processing File: Ambuja_Cements_Limited.xlsx ---
#   Successfully extracted data for: Ambuja Cements Limited
# --- Processing File: Ami_Organics_Limited.xlsx ---
#   Successfully extracted data for: Ami Organics Limited
# --- Processing File: AMRUTANJAN_HEALTH_CARE_LIMITED.xlsx ---
#   Successfully extracted data for: Amrutanjan Health Care Limited
# --- Processing File: ANAND_RATHI_WEALTH_LIMITED.xlsx ---
#   Successfully extracted data for: Anand Rathi Wealth Limited
# --- Processing File: Anant_Raj_Limited.xlsx ---
#   Successfully extracted data for: Anant Raj Limited
# --- Processing File: Andhra_Paper_Limited.xlsx ---
#   Successfully extracted data for: Andhra Paper Limited
# --- Processing File: Angel_One_Limited.xlsx ---
#   Successfully extracted data for: Angel One Limited
#   Extracted Phone: 18001020
# --- Processing File: Anjani_Portland_Cement_Limited.xlsx ---
#   Successfully extracted data for: Anjani Portland Cement Limited
# --- Processing File: Antony_Waste_Handling_Cell_Limited.xlsx ---
#   Successfully extracted data for: Antony Waste Handling Cell Limited
# --- Processing File: Anupam_Rasayan_India_Limited.xlsx ---
#   Successfully extracted data for: Anupam Rasayan India Limited
# --- Processing File: APAR_Industries_Limited.xlsx ---
#   Successfully extracted data for: APAR Industries Limited
# --- Processing File: Apcotex_Industries_Limited.xlsx ---
#   Successfully extracted data for: Apcotex Industries Limited
# --- Processing File: Apeejay_Surrendra_Park_Hotels_Limited.xlsx ---
#   Successfully extracted data for: Apeejay Surrendra Park Hotels Limited
#   Extracted Phone: - 1800 102 7175
# --- Processing File: APEX_FROZEN_FOODS_LIMITED.xlsx ---
#   Successfully extracted data for: Apex Frozen Foods Limited
# --- Processing File: APL_Apollo_Tubes_Limited.xlsx ---
#   Successfully extracted data for: APL Apollo Tubes Limited
# --- Processing File: APOLLO_HOSPITALS_ENTERPRISE_LIMITED.xlsx ---
#   Successfully extracted data for: Apollo Hospitals Enterprise Limited
# --- Processing File: Apollo_Micro_Systems_Limited.xlsx ---
#   Successfully extracted data for: Apollo Micro Systems Limited
# --- Processing File: Apollo_Pipes_Limited.xlsx ---
#   Successfully extracted data for: Apollo Pipes Limited
# --- Processing File: Apollo_Tyres_Limited.xlsx ---
#   Successfully extracted data for: Apollo Tyres Limited
#   Extracted Phone: 1800-212-7070
# --- Processing File: APTECH_LIMITED.xlsx ---
#   Successfully extracted data for: Aptech Limited
# --- Processing File: Aptus_Value_Housing_Finance_India_Limited.xlsx ---
#   Successfully extracted data for: Aptus Value Housing Finance India Limited
# --- Processing File: Archean_Chemical_Industries_Limited.xlsx ---
#   Successfully extracted data for: Archean Chemical Industries Limited
# --- Processing File: ARIHANT_CAPITAL_MARKETS_LIMITED.xlsx ---
#   Successfully extracted data for: Arihant Capital Markets Limited
# --- Processing File: Arman_Financial_Services_Limited.xlsx ---
#   Successfully extracted data for: Arman Financial Services Limited
# --- Processing File: Artemis_Medicare_Services_Limited.xlsx ---
#   Successfully extracted data for: Artemis Medicare Services Limited
# --- Processing File: Arvind_Fashions_Limited.xlsx ---
#   Successfully extracted data for: Arvind Fashions Limited
# --- Processing File: ARVIND_LIMITED.xlsx ---
#   Successfully extracted data for: Arvind Limited
# --- Processing File: Arvind_SmartSpaces_Limited.xlsx ---
#   Successfully extracted data for: Arvind SmartSpaces Limited
# --- Processing File: Asahi_India_Glass_Limited.xlsx ---
#   Successfully extracted data for: Asahi India Glass Limited
# --- Processing File: ASHAPURA_MINECHEM_LIMITED.xlsx ---
#   Successfully extracted data for: Ashapura Minechem Limited
# --- Processing File: ASHIANA_HOUSING_LIMITED.xlsx ---
#   Successfully extracted data for: Ashiana Housing Limited
# --- Processing File: ASHOKA_BUILDCON_LIMITED.xlsx ---
#   Successfully extracted data for: Ashoka Buildcon Limited
# --- Processing File: Ashok_Leyland_Limited.xlsx ---
#   Successfully extracted data for: Ashok Leyland Limited
#   Extracted Phone: 1800-266-3340, 1800-1022-666, 1800-419-19216
# --- Processing File: Asian_Paints_Limited.xlsx ---
#   Successfully extracted data for: Asian Paints Limited
# --- Processing File: ASK_Automotive_Limited.xlsx ---
#   Successfully extracted data for: ASK Automotive Limited
#   Extracted Phone: 011-28759605
# --- Processing File: ASTEC_LIFESCIENCES_LIMITED.xlsx ---
#   Successfully extracted data for: Astec Lifesciences Limited
# --- Processing File: Aster_DM_Healthcare_Limited.xlsx ---
#   Successfully extracted data for: Aster DM Healthcare Limited
# --- Processing File: Astral_Limited.xlsx ---
#   Successfully extracted data for: Astral Limited
#   Extracted Phone: 18002337957, 7311103331
# --- Processing File: AstraZeneca_Pharma_India_Limited.xlsx ---
#   Successfully extracted data for: AstraZeneca Pharma India Limited
# --- Processing File: ASTRA_MICROWAVE_PRODUCTS_LIMITED.xlsx ---
#   Successfully extracted data for: Astra Microwave Products Limited
# --- Processing File: Atul_Limited.xlsx ---
#   Successfully extracted data for: Atul Limited
# --- Processing File: Aurionpro_Solutions_Limited.xlsx ---
#   Successfully extracted data for: Aurionpro Solutions Limited
# --- Processing File: Aurobindo_Pharma_Limited.xlsx ---
#   Successfully extracted data for: Aurobindo Pharma Limited
# --- Processing File: Authum_Investment_&_Infrastructure_Limited.xlsx ---
#   Successfully extracted data for: Authum Investment & Infrastructure Limited
# --- Processing File: AUTOLINE_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Autoline Industries Limited
# --- Processing File: Automotive_Axles_Limited.xlsx ---
#   Successfully extracted data for: Automotive Axles Limited
# --- Processing File: Automotive_Stampings_and_Assemblies_Limited.xlsx ---
#   Successfully extracted data for: Automotive Stampings and Assemblies Limited
# --- Processing File: AU_Small_Finance_Bank_Limited.xlsx ---
#   Successfully extracted data for: AU Small Finance Bank Limited
# --- Processing File: Avadh_Sugar_&_Energy_Limited.xlsx ---
#   Successfully extracted data for: Avadh Sugar & Energy Limited
# --- Processing File: Avalon_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Avalon Technologies Limited
# --- Processing File: Avanti_Feeds_Limited.xlsx ---
#   Successfully extracted data for: Avanti Feeds Limited
# --- Processing File: Avenue_Supermarts_Limited.xlsx ---
#   Successfully extracted data for: Avenue Supermarts Limited
# --- Processing File: AVT_NATURAL_PRODUCTS_LIMITED.xlsx ---
#   Successfully extracted data for: Avt Natural Products Limited
# --- Processing File: AXISCADES_Technologies_Limited.xlsx ---
#   Successfully extracted data for: AXISCADES Technologies Limited
# --- Processing File: Axis_Bank_Limited.xlsx ---
#   Successfully extracted data for: Axis Bank Limited
# --- Processing File: Azad_Engineering_Limited.xlsx ---
#   Successfully extracted data for: Azad Engineering Limited
# --- Processing File: BAJAJ_AUTO_LIMITED.xlsx ---
#   Successfully extracted data for: Bajaj Auto Limited
# --- Processing File: Bajaj_Consumer_Care_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Consumer Care Limited
# --- Processing File: BAJAJ_ELECTRICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Bajaj Electricals Limited
# --- Processing File: Bajaj_Finance_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Finance Limited
# --- Processing File: Bajaj_Finserv_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Finserv Limited
# --- Processing File: Bajaj_Healthcare_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Healthcare Limited
# --- Processing File: Bajaj_Hindusthan_Sugar_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Hindusthan Sugar Limited
# --- Processing File: Bajaj_Holdings_&_Investment_Limited.xlsx ---
#   Successfully extracted data for: Bajaj Holdings & Investment Limited
# --- Processing File: Bajel_Projects_Limited.xlsx ---
#   Successfully extracted data for: Bajel Projects Limited
# --- Processing File: Balaji_Amines_Limited.xlsx ---
#   Successfully extracted data for: Balaji Amines Limited
# --- Processing File: Balaxi_Pharmaceuticals_Limited.xlsx ---
#   Successfully extracted data for: Balaxi Pharmaceuticals Limited
# --- Processing File: BALKRISHNA_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Balkrishna Industries Limited
# --- Processing File: Balmer_Lawrie_&_Company_Limited.xlsx ---
#   Successfully extracted data for: Balmer Lawrie & Company Limited
# --- Processing File: Balrampur_Chini_Mills_Limited.xlsx ---
#   Successfully extracted data for: Balrampur Chini Mills Limited
# --- Processing File: BALU_FORGE_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Balu Forge Industries Limited
# --- Processing File: BANARAS_BEADS_LIMITED.xlsx ---
#   Successfully extracted data for: Banaras Beads Limited
# --- Processing File: BANCO_PRODUCTS_(I)_LIMITED.xlsx ---
#   Successfully extracted data for: Banco Products (I) Limited
# --- Processing File: Bandhan_Bank_Limited.xlsx ---
#   Successfully extracted data for: Bandhan Bank Limited
# --- Processing File: Bank_of_Baroda.xlsx ---
#   Successfully extracted data for: Bank of Baroda
# --- Processing File: BANK_OF_INDIA.xlsx ---
#   Successfully extracted data for: Bank Of India
# --- Processing File: BANK_OF_MAHARASHTRA.xlsx ---
#   Successfully extracted data for: Bank Of Maharashtra
# --- Processing File: BANNARI_AMMAN_SUGARS_LIMITED.xlsx ---
#   Successfully extracted data for: Bannari Amman Sugars Limited
# --- Processing File: Barbeque_Nation_Hospitality_Limited.xlsx ---
#   Successfully extracted data for: Barbeque Nation Hospitality Limited
# --- Processing File: BASF_India_Limited.xlsx ---
#   Successfully extracted data for: BASF India Limited
# --- Processing File: Bata_India_Limited.xlsx ---
#   Successfully extracted data for: Bata India Limited
# --- Processing File: BCL_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Bcl Industries Limited
# --- Processing File: BEML_Limited.xlsx ---
#   Successfully extracted data for: BEML Limited
# --- Processing File: BERGER_PAINTS_(I)_LIMITED.xlsx ---
#   Successfully extracted data for: Berger Paints (I) Limited
#   Extracted Phone: 1800 103 6030, +91 33 2229 9724, 2229 6005, +91 33 2249 9009
# --- Processing File: BEST_AGROLIFE_LIMITED.xlsx ---
#   Successfully extracted data for: Best Agrolife Limited
# --- Processing File: BF_INVESTMENT_LIMITED.xlsx ---
#   Successfully extracted data for: Bf Investment Limited
# --- Processing File: BF_UTILITIES_LIMITED.xlsx ---
#   Successfully extracted data for: Bf Utilities Limited
# --- Processing File: Bhageria_Industries_Limited.xlsx ---
#   Successfully extracted data for: Bhageria Industries Limited
# --- Processing File: BHAGIRADHA_CHEMICALS_&_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Bhagiradha Chemicals & Industries Limited
# --- Processing File: Bhansali_Engineering_Polymers_Limited.xlsx ---
#   Successfully extracted data for: Bhansali Engineering Polymers Limited
# --- Processing File: Bharat_Bijlee_Limited.xlsx ---
#   Successfully extracted data for: Bharat Bijlee Limited
# --- Processing File: Bharat_Dynamics_Limited.xlsx ---
#   Successfully extracted data for: Bharat Dynamics Limited
# --- Processing File: Bharat_Electronics_Limited.xlsx ---
#   Successfully extracted data for: Bharat Electronics Limited
# --- Processing File: Bharat_Forge_Limited.xlsx ---
#   Successfully extracted data for: Bharat Forge Limited
# --- Processing File: BHARAT_HEAVY_ELECTRICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Bharat Heavy Electricals Limited
# --- Processing File: Bharat_Petroleum_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Bharat Petroleum Corporation Limited
#   Extracted Phone: 1800 22 4344
# --- Processing File: BHARAT_RASAYAN_LIMITED.xlsx ---
#   Successfully extracted data for: Bharat Rasayan Limited
# --- Processing File: BHARAT_WIRE_ROPES_LIMITED.xlsx ---
#   Successfully extracted data for: Bharat Wire Ropes Limited
# --- Processing File: Bharti_Airtel_Limited.xlsx ---
#   Successfully extracted data for: Bharti Airtel Limited
# --- Processing File: Bharti_Hexacom_Limited.xlsx ---
#   Successfully extracted data for: Bharti Hexacom Limited
# --- Processing File: BIGBLOC_CONSTRUCTION_LIMITED.xlsx ---
#   Successfully extracted data for: Bigbloc Construction Limited
# --- Processing File: BIKAJI_FOODS_INTERNATIONAL_LIMITED.xlsx ---
#   Successfully extracted data for: Bikaji Foods International Limited
# --- Processing File: Biocon_Limited.xlsx ---
#   Successfully extracted data for: Biocon Limited
# --- Processing File: Birlasoft_Limited.xlsx ---
#   Successfully extracted data for: Birlasoft Limited
# --- Processing File: Birla_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Birla Corporation Limited
# --- Processing File: Black_Box_Limited.xlsx ---
#   Successfully extracted data for: Black Box Limited
# --- Processing File: BLISS_GVS_PHARMA_LIMITED.xlsx ---
#   Successfully extracted data for: Bliss Gvs Pharma Limited
# --- Processing File: BLS_E-SERVICES_LIMITED.xlsx ---
#   Successfully extracted data for: Bls E-Services Limited
# --- Processing File: BLS_International_Services_Limited.xlsx ---
#   Successfully extracted data for: BLS International Services Limited
# --- Processing File: Blue_Dart_Express_Limited.xlsx ---
#   Successfully extracted data for: Blue Dart Express Limited
#   Extracted Phone: 2022-2023
# --- Processing File: Blue_Jet_Healthcare_Limited.xlsx ---
#   Successfully extracted data for: Blue Jet Healthcare Limited
# --- Processing File: Blue_Star_Limited.xlsx ---
#   Successfully extracted data for: Blue Star Limited
# --- Processing File: BODAL_CHEMICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Bodal Chemicals Limited
# --- Processing File: Bombay_Burmah_Trading_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Bombay Burmah Trading Corporation Limited
# --- Processing File: BOMBAY_DYEING_&_MFG_COMPANY_LIMITED.xlsx ---
#   Successfully extracted data for: Bombay Dyeing & Mfg Company Limited
# --- Processing File: Borosil_Limited.xlsx ---
#   Successfully extracted data for: Borosil Limited
# --- Processing File: Borosil_Renewables_Limited.xlsx ---
#   Successfully extracted data for: Borosil Renewables Limited
# --- Processing File: BOSCH_LIMITED.xlsx ---
#   Successfully extracted data for: Bosch Limited
# --- Processing File: Brigade_Enterprises_Limited.xlsx ---
#   Successfully extracted data for: Brigade Enterprises Limited
#   Extracted Phone: 1800 102 9480, +91 96112 18222
# --- Processing File: Britannia_Industries_Limited.xlsx ---
#   Successfully extracted data for: Britannia Industries Limited
# --- Processing File: BSE_Limited.xlsx ---
#   Successfully extracted data for: BSE Limited
# --- Processing File: Butterfly_Gandhimathi_Appliances_Limited.xlsx ---
#   Successfully extracted data for: Butterfly Gandhimathi Appliances Limited
# --- Processing File: C.E._INFO_SYSTEMS_LIMITED.xlsx ---
#   Successfully extracted data for: C.E. Info Systems Limited
# --- Processing File: Camlin_Fine_Sciences_Limited.xlsx ---
#   Successfully extracted data for: Camlin Fine Sciences Limited
# --- Processing File: Campus_Activewear_Limited.xlsx ---
#   Successfully extracted data for: Campus Activewear Limited
#   Extracted Phone: - 9667706012
# --- Processing File: Canara_Bank.xlsx ---
#   Successfully extracted data for: Indian Overseas Bank
# --- Processing File: Cantabil_Retail_India_Limited.xlsx ---
#   Successfully extracted data for: Cantabil Retail India Limited
# --- Processing File: Can_Fin_Homes_Limited.xlsx ---
#   Successfully extracted data for: Can Fin Homes Limited
# --- Processing File: CAPACITE_INFRAPROJECTS_LIMITED.xlsx ---
#   Successfully extracted data for: Capacite Infraprojects Limited
# --- Processing File: Caplin_Point_Laboratories_Limited.xlsx ---
#   Successfully extracted data for: Caplin Point Laboratories Limited
# --- Processing File: CAPRI_GLOBAL_CAPITAL_LIMITED.xlsx ---
#   Successfully extracted data for: Capri Global Capital Limited
#   Extracted Phone: +91 9179 121 021, 1800 102 1021
# --- Processing File: Carborundum_Universal_Limited.xlsx ---
#   Successfully extracted data for: Carborundum Universal Limited
# --- Processing File: CARE_Ratings_Limited.xlsx ---
#   Successfully extracted data for: CARE Ratings Limited
# --- Processing File: CARTRADE_TECH_LIMITED.xlsx ---
#   Successfully extracted data for: Cartrade Tech Limited
# --- Processing File: Carysil_Limited.xlsx ---
#   Successfully extracted data for: Carysil Limited
# --- Processing File: Castrol_India_Limited.xlsx ---
#   Successfully extracted data for: Castrol India Limited
#   Extracted Phone: 18002098100, 1800222100
# --- Processing File: CCL_PRODUCTS_(INDIA)_LIMITED.xlsx ---
#   Successfully extracted data for: Ccl Products (India) Limited
# --- Processing File: CEAT_Limited.xlsx ---
#   Successfully extracted data for: CEAT Limited
#   Extracted Phone: 1800 22 1213
# --- Processing File: CELLO_WORLD_LIMITED.xlsx ---
#   Successfully extracted data for: Cello World Limited
# --- Processing File: Central_Bank_of_India.xlsx ---
#   Successfully extracted data for: Central Bank of India
#   Extracted Phone: 18003030
# --- Processing File: Central_Depository_Services_(India)_Limited.xlsx ---
#   Successfully extracted data for: Central Depository Services (India) Limited
# --- Processing File: Centrum_Capital_Limited.xlsx ---
#   Successfully extracted data for: Centrum Capital Limited
# --- Processing File: Centum_Electronics_Limited.xlsx ---
#   Successfully extracted data for: Centum Electronics Limited
# --- Processing File: Century_Enka_Limited.xlsx ---
#   Successfully extracted data for: Century Enka Limited
# --- Processing File: Century_Plyboards_(India)_Limited.xlsx ---
#   Successfully extracted data for: Century Plyboards (India) Limited
# --- Processing File: Century_Textiles_&_Industries_Limited.xlsx ---
#   Successfully extracted data for: Century Textiles & Industries Limited
# --- Processing File: Cera_Sanitaryware_Limited.xlsx ---
#   Successfully extracted data for: Cera Sanitaryware Limited
# --- Processing File: CESC_Limited.xlsx ---
#   Successfully extracted data for: CESC Limited
# --- Processing File: CG_Power_and_Industrial_Solutions_Limited.xlsx ---
#   Successfully extracted data for: CG Power and Industrial Solutions Limited
# --- Processing File: Chalet_Hotels_Limited.xlsx ---
#   Successfully extracted data for: Chalet Hotels Limited
# --- Processing File: CHAMAN_LAL_SETIA_EXPORTS_LIMITED.xlsx ---
#   Successfully extracted data for: Chaman Lal Setia Exports Limited
# --- Processing File: CHEMCON_SPECIALITY_CHEMICALS_LIMITED.xlsx ---
#   Successfully extracted data for: Chemcon Speciality Chemicals Limited
# --- Processing File: Chemplast_Sanmar_Limited.xlsx ---
#   Successfully extracted data for: Chemplast Sanmar Limited
# --- Processing File: CHENNAI_PETROLEUM_CORPORATION_LIMITED.xlsx ---
#   Successfully extracted data for: Chennai Petroleum Corporation Limited
# --- Processing File: Choice_International_Limited.xlsx ---
#   Successfully extracted data for: Choice International Limited
# --- Processing File: Cholamandalam_Financial_Holdings_Limited.xlsx ---
#   Successfully extracted data for: Cholamandalam Financial Holdings Limited
# --- Processing File: Cholamandalam_Investment_and_Finance_Company_Limited.xlsx ---
#   Successfully extracted data for: Cholamandalam Investment and Finance Company Limited
# --- Processing File: CIE_Automotive_India_Limited.xlsx ---
#   Successfully extracted data for: CIE Automotive India Limited
# --- Processing File: Cigniti_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Cigniti Technologies Limited
# --- Processing File: Cipla_Limited.xlsx ---
#   Successfully extracted data for: Cipla Limited
# --- Processing File: CITY_UNION_BANK_LIMITED.xlsx ---
#   Successfully extracted data for: City Union Bank Limited
# --- Processing File: Clean_Science_and_Technology_Limited.xlsx ---
#   Successfully extracted data for: Clean Science and Technology Limited
# --- Processing File: CMS_Info_Systems_Limited.xlsx ---
#   Successfully extracted data for: CMS Info Systems Limited
# --- Processing File: COAL_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Coal India Limited
# --- Processing File: Cochin_Shipyard_Limited.xlsx ---
#   Successfully extracted data for: Cochin Shipyard Limited
# --- Processing File: Coforge_Limited.xlsx ---
#   Successfully extracted data for: Coforge Limited
# --- Processing File: Colgate_Palmolive_(India)_Limited.xlsx ---
#   Successfully extracted data for: Colgate Palmolive (India) Limited
# --- Processing File: Computer_Age_Management_Services_Limited.xlsx ---
#   Successfully extracted data for: Computer Age Management Services Limited
# --- Processing File: Concord_Biotech_Limited.xlsx ---
#   Successfully extracted data for: Concord Biotech Limited
# --- Processing File: CONFIDENCE_PETROLEUM_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Confidence Petroleum India Limited
# --- Processing File: Container_Corporation_of_India_Limited.xlsx ---
#   Successfully extracted data for: Container Corporation of India Limited
# --- Processing File: Control_Print_Limited.xlsx ---
#   Successfully extracted data for: Control Print Limited
# --- Processing File: COROMANDEL_INTERNATIONAL_LIMITED.xlsx ---
#   Successfully extracted data for: Coromandel International Limited
# --- Processing File: COSMO_FIRST_LIMITED.xlsx ---
#   Successfully extracted data for: Cosmo First Limited
# --- Processing File: Craftsman_Automation_Limited.xlsx ---
#   Successfully extracted data for: Craftsman Automation Limited
# --- Processing File: CreditAccess_Grameen_Limited.xlsx ---
#   Successfully extracted data for: CreditAccess Grameen Limited
# --- Processing File: Crompton_Greaves_Consumer_Electricals_Limited.xlsx ---
#   Successfully extracted data for: Crompton Greaves Consumer Electricals Limited
# --- Processing File: CSB_Bank_Limited.xlsx ---
#   Successfully extracted data for: CSB Bank Limited
# --- Processing File: Cummins_India_Limited.xlsx ---
#   Successfully extracted data for: Cummins India Limited
# --- Processing File: CUPID_LIMITED.xlsx ---
#   Successfully extracted data for: Cupid Limited
# --- Processing File: Cyient_DLM_Limited.xlsx ---
#   Successfully extracted data for: Cyient DLM Limited
# --- Processing File: Cyient_Limited.xlsx ---
#   Successfully extracted data for: Cyient Limited
# --- Processing File: D.B.Corp_Limited.xlsx ---
#   Successfully extracted data for: D.B.Corp Limited
# --- Processing File: D._P._Abhushan_Limited.xlsx ---
#   Successfully extracted data for: D. P. Abhushan Limited
# --- Processing File: Dabur_India_Limited.xlsx ---
#   Successfully extracted data for: Dabur India Limited
#   Extracted Phone: 18001031644
# --- Processing File: Dalmia_Bharat_Limited.xlsx ---
#   Successfully extracted data for: Dalmia Bharat Limited
# --- Processing File: Dalmia_Bharat_Sugar_and_Industries_Limited.xlsx ---
#   Successfully extracted data for: Dalmia Bharat Sugar and Industries Limited
# --- Processing File: Datamatics_Global_Services_Limited.xlsx ---
#   Successfully extracted data for: Datamatics Global Services Limited
# --- Processing File: Data_Patterns_(India)_Limited.xlsx ---
#   Successfully extracted data for: Data Patterns (India) Limited
# --- Processing File: DCB_Bank_Limited.xlsx ---
#   Successfully extracted data for: DCB Bank Limited
# --- Processing File: DCM_NOUVELLE_LIMITED.xlsx ---
#   Successfully extracted data for: Dcm Nouvelle Limited
# --- Processing File: DCM_Shriram_Industries_Limited.xlsx ---
#   Successfully extracted data for: DCM Shriram Industries Limited
# --- Processing File: DCM_Shriram_Limited.xlsx ---
#   Successfully extracted data for: DCM Shriram Limited
# --- Processing File: DCW_Limited.xlsx ---
#   Successfully extracted data for: DCW Limited
# --- Processing File: DCX_Systems_Limited.xlsx ---
#   Successfully extracted data for: DCX Systems Limited
# --- Processing File: DEEPAK_FERTILIZERS_AND_PETROCHEMICALS_CORPORATION_LIMITED.xlsx ---
#   Successfully extracted data for: Deepak Fertilizers And Petrochemicals Corporation Limited
# --- Processing File: Deepak_Nitrite_Limited.xlsx ---
#   Successfully extracted data for: Deepak Nitrite Limited
# --- Processing File: Deep_Industries_Limited.xlsx ---
#   Successfully extracted data for: Deep Industries Limited
# --- Processing File: DEE_Development_Engineers_Limited.xlsx ---
#   Successfully extracted data for: DEE Development Engineers Limited
# --- Processing File: Delhivery_Limited.xlsx ---
#   Successfully extracted data for: Delhivery Limited
# --- Processing File: Delta_Corp_Limited.xlsx ---
#   Successfully extracted data for: Delta Corp Limited
# --- Processing File: DEN_Networks_Limited.xlsx ---
#   Successfully extracted data for: DEN Networks Limited
# --- Processing File: Devyani_International_Limited.xlsx ---
#   Successfully extracted data for: Devyani International Limited
# --- Processing File: Dhampur_Bio_Organics_Limited.xlsx ---
#   Successfully extracted data for: Dhampur Bio Organics Limited
# --- Processing File: DHAMPUR_SUGAR_MILLS_LIMITED.xlsx ---
#   Successfully extracted data for: Dhampur Sugar Mills Limited
# --- Processing File: Dhani_Services_Limited.xlsx ---
#   Successfully extracted data for: Dhani Services Limited
# --- Processing File: Dhanuka_Agritech_Limited.xlsx ---
#   Successfully extracted data for: Dhanuka Agritech Limited
# --- Processing File: Dhunseri_Ventures_Limited.xlsx ---
#   Successfully extracted data for: Dhunseri Ventures Limited
# --- Processing File: Diamond_Power_Infrastructure_Limited.xlsx ---
#   Successfully extracted data for: Diamond Power Infrastructure Limited
# --- Processing File: Dilip_Buildcon_Limited.xlsx ---
#   Successfully extracted data for: Dilip Buildcon Limited
# --- Processing File: Dishman_Carbogen_Amcis_Limited.xlsx ---
#   Successfully extracted data for: Dishman Carbogen Amcis Limited
# --- Processing File: Dish_TV_India_Limited.xlsx ---
#   Successfully extracted data for: Dish TV India Limited
# --- Processing File: Divgi_TorqTransfer_Systems_Limited.xlsx ---
#   Successfully extracted data for: Divgi TorqTransfer Systems Limited
# --- Processing File: Divi's_Laboratories_Limited.xlsx ---
#   Successfully extracted data for: Divi's Laboratories Limited
# --- Processing File: Dixon_Technologies_(India)_Limited.xlsx ---
#   Successfully extracted data for: Dixon Technologies (India) Limited
# --- Processing File: DLF_Limited.xlsx ---
#   Successfully extracted data for: DLF Limited
# --- Processing File: DMCC_Speciality_Chemicals_Limited.xlsx ---
#   Successfully extracted data for: DMCC Speciality Chemicals Limited
# --- Processing File: DODLA_DAIRY_LIMITED.xlsx ---
#   Successfully extracted data for: Dodla Dairy Limited
# --- Processing File: Dolat_Algotech_Limited.xlsx ---
#   Successfully extracted data for: Dolat Algotech Limited
# --- Processing File: Dollar_Industries_Limited.xlsx ---
#   Successfully extracted data for: Dollar Industries Limited
# --- Processing File: DOMS_Industries_Limited.xlsx ---
#   Successfully extracted data for: DOMS Industries Limited
# --- Processing File: DPSC_Limited.xlsx ---
#   Successfully extracted data for: DPSC Limited
#   Extracted Phone: 18001023783
# --- Processing File: Dr._Lal_Path_Labs_Limited.xlsx ---
#   Successfully extracted data for: Dr. Lal Path Labs Limited
# --- Processing File: DR._REDDY'S_LABORATORIES_LIMITED.xlsx ---
#   Successfully extracted data for: Dr. Reddy'S Laboratories Limited
# --- Processing File: Dreamfolks_Services_Limited.xlsx ---
#   Successfully extracted data for: Dreamfolks Services Limited
#   Extracted Phone: - 1800 1234 109
# --- Processing File: Dredging_Corporation_of_India_Limited.xlsx ---
#   Successfully extracted data for: Dredging Corporation of India Limited
# --- Processing File: Dwarikesh_Sugar_Industries_Limited.xlsx ---
#   Successfully extracted data for: Dwarikesh Sugar Industries Limited
# --- Processing File: Dynamatic_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Dynamatic Technologies Limited
# --- Processing File: Easy_Trip_Planners_Limited.xlsx ---
#   Successfully extracted data for: Easy Trip Planners Limited
# --- Processing File: eClerx_Services_Limited.xlsx ---
#   Successfully extracted data for: eClerx Services Limited
# --- Processing File: Edelweiss_Financial_Services_Limited.xlsx ---
#   Successfully extracted data for: Edelweiss Financial Services Limited
# --- Processing File: EICHER_MOTORS_LIMITED.xlsx ---
#   Successfully extracted data for: Eicher Motors Limited
# --- Processing File: EID_Parry_India_Limited.xlsx ---
#   Successfully extracted data for: EID Parry India Limited
# --- Processing File: EIH_Associated_Hotels_Limited.xlsx ---
#   Successfully extracted data for: EIH Associated Hotels Limited
# --- Processing File: EIH_LIMITED.xlsx ---
#   Successfully extracted data for: EIH Limited
# --- Processing File: Elecon_Engineering_Company_Limited.xlsx ---
#   Successfully extracted data for: Elecon Engineering Company Limited
# --- Processing File: Electronics_Mart_India_Limited.xlsx ---
#   Successfully extracted data for: Electronics Mart India Limited
# --- Processing File: Electrosteel_Castings_Limited.xlsx ---
#   Successfully extracted data for: Electrosteel Castings Limited
# --- Processing File: Elgi_Equipments_Limited.xlsx ---
#   Successfully extracted data for: Elgi Equipments Limited
# --- Processing File: Emami_Limited.xlsx ---
#   Successfully extracted data for: Emami Limited
# --- Processing File: EMAMI_PAPER_MILLS_LIMITED.xlsx ---
#   Successfully extracted data for: Emami Paper Mills Limited
# --- Processing File: EMS_LIMITED.xlsx ---
#   Successfully extracted data for: Ems Limited
# --- Processing File: EMUDHRA_LIMITED.xlsx ---
#   Successfully extracted data for: Emudhra Limited
# --- Processing File: Endurance_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Endurance Technologies Limited
#   Extracted Phone: 0240 2569723, 8010187593
# --- Processing File: Engineers_India_Limited.xlsx ---
#   Successfully extracted data for: Engineers India Limited
# --- Processing File: Entero_Healthcare_Solutions_Limited.xlsx ---
#   Successfully extracted data for: Entero Healthcare Solutions Limited
# --- Processing File: Entertainment_Network_(India)_Limited.xlsx ---
#   Successfully extracted data for: Entertainment Network (India) Limited
# --- Processing File: EPACK_Durable_Limited.xlsx ---
#   Successfully extracted data for: EPACK Durable Limited
# --- Processing File: Epigral_Limited.xlsx ---
#   Successfully extracted data for: Epigral Limited
# --- Processing File: EPL_Limited.xlsx ---
#   Successfully extracted data for: EPL Limited
# --- Processing File: Equinox_India_Developments_Limited.xlsx ---
#   Successfully extracted data for: Equinox India Developments Limited
# --- Processing File: Equitas_Small_Finance_Bank_Limited.xlsx ---
#   Successfully extracted data for: Equitas Small Finance Bank Limited
# --- Processing File: ERIS_LIFESCIENCES_LIMITED.xlsx ---
#   Successfully extracted data for: Eris Lifesciences Limited
#   Extracted Phone: 18002700390
# --- Processing File: ESAB_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Esab India Limited
# --- Processing File: ESAF_Small_Finance_Bank_Limited.xlsx ---
#   Successfully extracted data for: ESAF Small Finance Bank Limited
# --- Processing File: Escorts_Kubota_Limited.xlsx ---
#   Successfully extracted data for: Escorts Kubota Limited
# --- Processing File: Ester_Industries_Limited.xlsx ---
#   Successfully extracted data for: Ester Industries Limited
# --- Processing File: ETHOS_LIMITED.xlsx ---
#   Successfully extracted data for: Ethos Limited
# --- Processing File: EVEREADY_INDUSTRIES_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Eveready Industries India Limited
# --- Processing File: Everest_Industries_Limited.xlsx ---
#   Successfully extracted data for: Everest Industries Limited
# --- Processing File: Everest_Kanto_Cylinder_Limited.xlsx ---
#   Successfully extracted data for: Everest Kanto Cylinder Limited
# --- Processing File: Excel_Industries_Limited.xlsx ---
#   Successfully extracted data for: Excel Industries Limited
# --- Processing File: Exicom_Tele-Systems_Limited.xlsx ---
#   Successfully extracted data for: Exicom Tele-Systems Limited
# --- Processing File: Exide_Industries_Limited.xlsx ---
#   Successfully extracted data for: Exide Industries Limited
# --- Processing File: EXPLEO_SOLUTIONS_LIMITED.xlsx ---
#   Successfully extracted data for: Expleo Solutions Limited
# --- Processing File: FAIRCHEM_ORGANICS_LIMITED.xlsx ---
#   Successfully extracted data for: Fairchem Organics Limited
# --- Processing File: Faze_Three_Limited.xlsx ---
#   Successfully extracted data for: Faze Three Limited
# --- Processing File: FDC_Limited.xlsx ---
#   Successfully extracted data for: FDC Limited
#   Extracted Phone: 1800 266 9347
# --- Processing File: Fedbank_Financial_Services_Limited.xlsx ---
#   Successfully extracted data for: Fedbank Financial Services Limited
#   Extracted Phone: 08069291313, 7418128882
# --- Processing File: Federal-Mogul_Goetze_(India)_Limited..xlsx ---
#   Successfully extracted data for: Federal-Mogul Goetze (India) Limited.
# --- Processing File: FERTILIZERS_AND_CHEMICALS_TRAVANCORE_LIMITED.xlsx ---
#   Successfully extracted data for: Fertilizers And Chemicals Travancore Limited
# --- Processing File: FIEM_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Fiem Industries Limited
# --- Processing File: FILATEX_FASHIONS_LIMITED.xlsx ---
#   Successfully extracted data for: Filatex Fashions Limited
# --- Processing File: Filatex_India_Limited.xlsx ---
#   Successfully extracted data for: Filatex India Limited
# --- Processing File: Fineotex_Chemical_Limited.xlsx ---
#   Successfully extracted data for: Fineotex Chemical Limited
# --- Processing File: FINE_ORGANIC_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Fine Organic Industries Limited
# --- Processing File: Finolex_Cables_Limited.xlsx ---
#   Successfully extracted data for: Finolex Cables Limited
#   Extracted Phone: 1800 209 0166, - 2750 6219
# --- Processing File: Finolex_Industries_Limited.xlsx ---
#   Successfully extracted data for: Finolex Industries Limited
# --- Processing File: Fino_Payments_Bank_Limited.xlsx ---
#   Successfully extracted data for: Fino Payments Bank Limited
#   Extracted Phone: 022 6868 1414
# --- Processing File: Firstsource_Solutions_Limited.xlsx ---
#   Successfully extracted data for: Firstsource Solutions Limited
# --- Processing File: Five-Star_Business_Finance_Limited.xlsx ---
#   Successfully extracted data for: Five-Star Business Finance Limited
# --- Processing File: Flair_Writing_Industries_Limited.xlsx ---
#   Successfully extracted data for: Flair Writing Industries Limited
# --- Processing File: Force_Motors_Limited.xlsx ---
#   Successfully extracted data for: Force Motors Limited
# --- Processing File: Fortis_Healthcare_Limited.xlsx ---
#   Successfully extracted data for: Fortis Healthcare Limited
# --- Processing File: FOSECO_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Foseco India Limited
# --- Processing File: FSN_E_Commerce_Ventures_Limited.xlsx ---
#   Successfully extracted data for: FSN E Commerce Ventures Limited
# --- Processing File: Fusion_Micro_Finance_Limited.xlsx ---
#   Successfully extracted data for: Fusion Micro Finance Limited
# --- Processing File: Future_Consumer_Limited.xlsx ---
#   Successfully extracted data for: Future Consumer Limited
# --- Processing File: GABRIEL_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Gabriel India Limited
# --- Processing File: GAIL_(India)_Limited.xlsx ---
#   Successfully extracted data for: GAIL (India) Limited
# --- Processing File: Galaxy_Surfactants_Limited.xlsx ---
#   Successfully extracted data for: Galaxy Surfactants Limited
# --- Processing File: Gallantt_Ispat_Limited.xlsx ---
#   Successfully extracted data for: Gallantt Ispat Limited
# --- Processing File: GANDHAR_OIL_REFINERY_(INDIA)_LIMITED.xlsx ---
#   Successfully extracted data for: Gandhar Oil Refinery (India) Limited
# --- Processing File: Ganesha_Ecosphere_Limited.xlsx ---
#   Successfully extracted data for: Ganesha Ecosphere Limited
# --- Processing File: GANESH_BENZOPLAST_LIMITED.xlsx ---
#   Successfully extracted data for: Ganesh Benzoplast Limited
# --- Processing File: Ganesh_Housing_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Ganesh Housing Corporation Limited
# --- Processing File: Garden_Reach_Shipbuilders_&_Engineers_Limited.xlsx ---
#   Successfully extracted data for: Garden Reach Shipbuilders & Engineers Limited
# --- Processing File: Garware_Hi-Tech_Films_Limited.xlsx ---
#   Successfully extracted data for: Garware Hi-Tech Films Limited
# --- Processing File: Garware_Technical_Fibres_Limited.xlsx ---
#   Successfully extracted data for: Garware Technical Fibres Limited
# --- Processing File: Gateway_Distriparks_Limited.xlsx ---
#   Successfully extracted data for: Gateway Distriparks Limited
# --- Processing File: General_Insurance_Corporation_of_India.xlsx ---
#   Successfully extracted data for: General Insurance Corporation of India
# --- Processing File: GENESYS_INTERNATIONAL_CORPORATION_LIMITED.xlsx ---
#   Successfully extracted data for: Genesys International Corporation Limited
# --- Processing File: GENSOL_ENGINEERING_LIMITED.xlsx ---
#   Successfully extracted data for: Gensol Engineering Limited
# --- Processing File: Genus_Power_Infrastructures_Limited.xlsx ---
#   Successfully extracted data for: Genus Power Infrastructures Limited
# --- Processing File: Geojit_Financial_Services_Limited.xlsx ---
#   Successfully extracted data for: Geojit Financial Services Limited
#   Extracted Phone: 1800-425-5501, 1800-103-5501
# --- Processing File: GE_Power_India_Limited.xlsx ---
#   Successfully extracted data for: GE Power India Limited
# --- Processing File: GFL_LIMITED.xlsx ---
#   Successfully extracted data for: GFL Limited
# --- Processing File: GHCL_Limited.xlsx ---
#   Successfully extracted data for: GHCL Limited
# --- Processing File: GIC_Housing_Finance_Limited.xlsx ---
#   Successfully extracted data for: GIC Housing Finance Limited
# --- Processing File: Gillette_India_Limited.xlsx ---
#   Successfully extracted data for: Gillette India Limited
#   Extracted Phone: 1800-202-1364, +91 22-24942113
# --- Processing File: GLAND_PHARMA_LIMITED.xlsx ---
#   Successfully extracted data for: Gland Pharma Limited
# --- Processing File: GlaxoSmithKline_Pharmaceuticals_Limited.xlsx ---
#   Successfully extracted data for: GlaxoSmithKline Pharmaceuticals Limited
#   Extracted Phone: 1800-2222-03, +91-22-24959595
# --- Processing File: Glenmark_Life_Sciences_Limited.xlsx ---
#   Successfully extracted data for: Glenmark Life Sciences Limited
# --- Processing File: Glenmark_Pharmaceuticals_Limited.xlsx ---
#   Successfully extracted data for: Glenmark Pharmaceuticals Limited
# --- Processing File: GLOBAL_HEALTH_LIMITED.xlsx ---
#   Successfully extracted data for: Global Health Limited
# --- Processing File: Globus_Spirits_Limited.xlsx ---
#   Successfully extracted data for: Globus Spirits Limited
# --- Processing File: Gloster_Limited.xlsx ---
#   Successfully extracted data for: Gloster Limited
# --- Processing File: GMM_Pfaudler_Limited.xlsx ---
#   Successfully extracted data for: GMM Pfaudler Limited
# --- Processing File: GMR_Airports_Infrastructure_Limited.xlsx ---
#   Successfully extracted data for: GMR Airports Infrastructure Limited
# --- Processing File: GM_BREWERIES_LIMITED.xlsx ---
#   Successfully extracted data for: Gm Breweries Limited
# --- Processing File: GOCL_Corporation_Limited.xlsx ---
#   Successfully extracted data for: GOCL Corporation Limited
# --- Processing File: GODAWARI_POWER_AND_ISPAT_LIMITED.xlsx ---
#   Successfully extracted data for: Godawari Power And Ispat Limited
# --- Processing File: GODFREY_PHILLIPS_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Godfrey Phillips India Limited
# --- Processing File: GODREJ_AGROVET_LIMITED.xlsx ---
#   Successfully extracted data for: Godrej Agrovet Limited
# --- Processing File: Godrej_Consumer_Products_Limited.xlsx ---
#   Successfully extracted data for: Godrej Consumer Products Limited
# --- Processing File: Godrej_Industries_Limited.xlsx ---
#   Successfully extracted data for: Godrej Industries Limited
# --- Processing File: Godrej_Properties_Limited.xlsx ---
#   Successfully extracted data for: Godrej Properties Limited
# --- Processing File: Gokaldas_Exports_Limited.xlsx ---
#   Successfully extracted data for: Gokaldas Exports Limited
# --- Processing File: Gokul_Agro_Resources_Limited.xlsx ---
#   Successfully extracted data for: Gokul Agro Resources Limited
# --- Processing File: Goldiam_International_Limited.xlsx ---
#   Successfully extracted data for: Goldiam International Limited
# --- Processing File: Goodluck_India_Limited.xlsx ---
#   Successfully extracted data for: Goodluck India Limited
# --- Processing File: GOPAL_SNACKS_LIMITED.xlsx ---
#   Successfully extracted data for: Gopal Snacks Limited
# --- Processing File: Go_Fashion_(India)_Limited.xlsx ---
#   Successfully extracted data for: Go Fashion (India) Limited
# --- Processing File: GRANULES_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Granules India Limited
# --- Processing File: GRAPHITE_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Graphite India Limited
# --- Processing File: Grasim_Industries_Limited.xlsx ---
#   Successfully extracted data for: Grasim Industries Limited
# --- Processing File: Gravita_India_Limited.xlsx ---
#   Successfully extracted data for: Gravita India Limited
# --- Processing File: Greaves_Cotton_Limited.xlsx ---
#   Successfully extracted data for: Greaves Cotton Limited
# --- Processing File: GREENLAM_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Greenlam Industries Limited
# --- Processing File: Greenpanel_Industries_Limited.xlsx ---
#   Successfully extracted data for: Greenpanel Industries Limited
# --- Processing File: GREENPLY_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Greenply Industries Limited
# --- Processing File: Grindwell_Norton_Limited.xlsx ---
#   Successfully extracted data for: Grindwell Norton Limited
# --- Processing File: GRM_OVERSEAS_LIMITED.xlsx ---
#   Successfully extracted data for: Grm Overseas Limited
# --- Processing File: GRP_Limited.xlsx ---
#   Successfully extracted data for: GRP Limited
# --- Processing File: GTL_Infrastructure_Limited.xlsx ---
#   Successfully extracted data for: GTL Infrastructure Limited
# --- Processing File: GTPL_HATHWAY_LIMITED.xlsx ---
#   Successfully extracted data for: Gtpl Hathway Limited
# ...
#   Successfully extracted data for: Thirumalai Chemicals Limited
# --- Processing File: Thomas_Cook__(India)__Limited.xlsx ---
#   Successfully extracted data for: Thomas Cook  (India)  Limited
# --- Processing File: Thyrocare_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Thyrocare Technologies Limited
#   Extracted Phone: 022 30900000, 67123400
# 3, 8422888222, 022 38002350
# 3, 9870666333
# --- Processing File: Tide_Water_Oil_Company_(India)_Limited.xlsx ---
#   Successfully extracted data for: Tide Water Oil Company (India) Limited
# --- Processing File: Tilaknagar_Industries_Limited.xlsx ---
#   Successfully extracted data for: Tilaknagar Industries Limited
# --- Processing File: Time_Technoplast_Limited.xlsx ---
#   Successfully extracted data for: Time Technoplast Limited
# --- Processing File: TIMKEN_INDIA_LIMITED.xlsx ---
#   Successfully extracted data for: Timken India Limited
# --- Processing File: Tips_Industries_Limited.xlsx ---
#   Successfully extracted data for: Tips Industries Limited
# --- Processing File: TITAGARH_RAIL_SYSTEMS_LIMITED.xlsx ---
#   Successfully extracted data for: Titagarh Rail Systems Limited
# --- Processing File: Titan_Company_Limited.xlsx ---
#   Successfully extracted data for: Titan Company Limited
# --- Processing File: Torrent_Pharmaceuticals_Limited.xlsx ---
#   Successfully extracted data for: Torrent Pharmaceuticals Limited
#   Extracted Phone: 1800-120-3001
# --- Processing File: Torrent_Power_Limited.xlsx ---
#   Successfully extracted data for: Torrent Power Limited
# --- Processing File: Transformers_and_Rectifiers_(India)_Limited.xlsx ---
#   Successfully extracted data for: Transformers and Rectifiers (India) Limited
# --- Processing File: Transport_Corporation_of_India_Limited.xlsx ---
#   Successfully extracted data for: Transport Corporation of India Limited
# --- Processing File: Trent_Limited.xlsx ---
#   Successfully extracted data for: Trent Limited
# --- Processing File: TRIDENT_LIMITED.xlsx ---
#   Successfully extracted data for: Trident Limited
# --- Processing File: Triveni_Engineering_&_Industries_Limited.xlsx ---
#   Successfully extracted data for: Triveni Engineering & Industries Limited
# --- Processing File: Triveni_Turbine_Limited.xlsx ---
#   Successfully extracted data for: Triveni Turbine Limited
# --- Processing File: TTK_Healthcare_Limited.xlsx ---
#   Successfully extracted data for: TTK Healthcare Limited
# --- Processing File: TTK_Prestige_Limited.xlsx ---
#   Successfully extracted data for: TTK Prestige Limited
# --- Processing File: Tube_Investments_of_India_Limited.xlsx ---
#   Successfully extracted data for: Tube Investments of India Limited
# --- Processing File: TVS_Holdings_Limited.xlsx ---
#   Successfully extracted data for: TVS Holdings Limited
# --- Processing File: TVS_Motor_Company_Limited.xlsx ---
#   Successfully extracted data for: TVS Motor Company Limited
# --- Processing File: TVS_Srichakra_Limited.xlsx ---
#   Successfully extracted data for: TVS Srichakra Limited
# --- Processing File: TVS_Supply_Chain_Solutions_Limited.xlsx ---
#   Successfully extracted data for: TVS Supply Chain Solutions Limited
# --- Processing File: TV_Today_Network_Limited.xlsx ---
#   Successfully extracted data for: TV Today Network Limited
# --- Processing File: UCO_BANK.xlsx ---
#   Successfully extracted data for: Uco Bank
#   Extracted Phone: 18001030123, 033-4455-7131
# --- Processing File: UDAIPUR_CEMENT_WORKS_LIMITED.xlsx ---
#   Successfully extracted data for: Udaipur Cement Works Limited
# --- Processing File: UFlex_Limited.xlsx ---
#   Successfully extracted data for: UFlex Limited
#   Extracted Phone: 22000-2018
# --- Processing File: UGRO_Capital_Limited.xlsx ---
#   Successfully extracted data for: UGRO Capital Limited
# --- Processing File: Ujjivan_Small_Finance_Bank_Limited.xlsx ---
#   Successfully extracted data for: Ujjivan Small Finance Bank Limited
# --- Processing File: UltraTech_Cement_Limited.xlsx ---
#   Successfully extracted data for: UltraTech Cement Limited
# --- Processing File: Unichem_Laboratories_Limited.xlsx ---
#   Successfully extracted data for: Unichem Laboratories Limited
# --- Processing File: UNION_BANK_OF_INDIA.xlsx ---
#   Successfully extracted data for: Union Bank Of India
# --- Processing File: Uniparts_India_Limited.xlsx ---
#   Successfully extracted data for: Uniparts India Limited
# --- Processing File: UNIPHOS_ENTERPRISES_LIMITED.xlsx ---
#   Successfully extracted data for: Uniphos Enterprises Limited
# --- Processing File: Unitech_Limited.xlsx ---
#   Successfully extracted data for: Unitech Limited
# --- Processing File: UNITED_BREWERIES_LIMITED.xlsx ---
#   Successfully extracted data for: United Breweries Limited
# --- Processing File: UNITED_DRILLING_TOOLS_LIMITED.xlsx ---
#   Successfully extracted data for: United Drilling Tools Limited
# --- Processing File: UNITED_SPIRITS_LIMITED.xlsx ---
#   Successfully extracted data for: United Spirits Limited
#   Extracted Phone: 1800-425-2433
# --- Processing File: Universal_Cables_Limited.xlsx ---
#   Successfully extracted data for: Universal Cables Limited
# --- Processing File: UNO_MINDA_LIMITED.xlsx ---
#   Successfully extracted data for: Uno Minda Limited
# --- Processing File: UPDATER_SERVICES_LIMITED.xlsx ---
#   Successfully extracted data for: Updater Services Limited
# --- Processing File: UPL_LIMITED.xlsx ---
#   Successfully extracted data for: Upl Limited
# --- Processing File: URJA_GLOBAL_LIMITED.xlsx ---
#   Successfully extracted data for: Urja Global Limited
# --- Processing File: Usha_Martin_Limited.xlsx ---
#   Successfully extracted data for: Usha Martin Limited
# --- Processing File: UTI_Asset_Management_Company_Limited.xlsx ---
#   Successfully extracted data for: UTI Asset Management Company Limited
#   Extracted Phone: 18002661230
# --- Processing File: Utkarsh_Small_Finance_Bank_Limited.xlsx ---
#   Successfully extracted data for: Utkarsh Small Finance Bank Limited
# --- Processing File: Uttam_Sugar_Mills_Limited.xlsx ---
#   Successfully extracted data for: Uttam Sugar Mills Limited
# --- Processing File: V-GUARD_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: V-Guard Industries Limited
#   Extracted Phone: 9633503333, 1800 103 1300, 1860 3000
# --- Processing File: V-MART_RETAIL_LIMITED.xlsx ---
#   Successfully extracted data for: V-Mart Retail Limited
#   Extracted Phone: +91 9027057057
# --- Processing File: V.S.T_TILLERS_TRACTORS_LIMITED.xlsx ---
#   Successfully extracted data for: V.S.T Tillers Tractors Limited
# --- Processing File: VADILAL_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Vadilal Industries Limited
# --- Processing File: Vaibhav_Global_Limited.xlsx ---
#   Successfully extracted data for: Vaibhav Global Limited
# --- Processing File: Vakrangee_Limited.xlsx ---
#   Successfully extracted data for: Vakrangee Limited
# --- Processing File: Valiant_Organics_Limited.xlsx ---
#   Successfully extracted data for: Valiant Organics Limited
# --- Processing File: Valor_Estate_Limited.xlsx ---
#   Successfully extracted data for: Valor Estate Limited
# --- Processing File: Vardhman_Acrylics_Limited.xlsx ---
#   Successfully extracted data for: Vardhman Acrylics Limited
# --- Processing File: Vardhman_Holdings_Limited.xlsx ---
#   Successfully extracted data for: Vardhman Holdings Limited
# --- Processing File: Vardhman_Special_Steels_Limited.xlsx ---
#   Successfully extracted data for: Vardhman Special Steels Limited
# --- Processing File: Vardhman_Textiles_Limited.xlsx ---
#   Successfully extracted data for: Vardhman Textiles Limited
# --- Processing File: Varroc_Engineering_Limited.xlsx ---
#   Successfully extracted data for: Varroc Engineering Limited
# --- Processing File: Varun_Beverages_Limited.xlsx ---
#   Successfully extracted data for: Varun Beverages Limited
# --- Processing File: VA_TECH_WABAG_LIMITED.xlsx ---
#   Successfully extracted data for: Va Tech Wabag Limited
# --- Processing File: Vedanta_Limited.xlsx ---
#   Successfully extracted data for: Vedanta Limited
# --- Processing File: Vedant_Fashions_Limited.xlsx ---
#   Successfully extracted data for: Vedant Fashions Limited
# --- Processing File: Venky's_(India)_Limited.xlsx ---
#   Successfully extracted data for: Venky's (India) Limited
# --- Processing File: VENUS_PIPES_&_TUBES_LIMITED.xlsx ---
#   Successfully extracted data for: Venus Pipes & Tubes Limited
# --- Processing File: VERANDA_LEARNING_SOLUTIONS_LIMITED.xlsx ---
#   Successfully extracted data for: Veranda Learning Solutions Limited
# --- Processing File: Vesuvius_India_Limited.xlsx ---
#   Successfully extracted data for: Vesuvius India Limited
# --- Processing File: VIDHI_SPECIALTY_FOOD_INGREDIENTS_LIMITED.xlsx ---
#   Successfully extracted data for: Vidhi Specialty Food Ingredients Limited
# --- Processing File: Vijaya_Diagnostic_Centre_Limited.xlsx ---
#   Successfully extracted data for: Vijaya Diagnostic Centre Limited
# --- Processing File: Vinati_Organics_Limited.xlsx ---
#   Successfully extracted data for: Vinati Organics Limited
# --- Processing File: Vindhya_Telelinks_Limited.xlsx ---
#   Successfully extracted data for: Vindhya Telelinks Limited
# --- Processing File: VIP_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Vip Industries Limited
# --- Processing File: Visaka_Industries_Limited.xlsx ---
#   Successfully extracted data for: Visaka Industries Limited
# --- Processing File: Vishnu_Chemicals_Limited.xlsx ---
#   Successfully extracted data for: Vishnu Chemicals Limited
# --- Processing File: VISHNU_PRAKASH_R_PUNGLIA_LIMITED.xlsx ---
#   Successfully extracted data for: Vishnu Prakash R Punglia Limited
# --- Processing File: Vodafone_Idea_Limited.xlsx ---
#   Successfully extracted data for: Vodafone Idea Limited
# --- Processing File: Voltamp_Transformers_Limited.xlsx ---
#   Successfully extracted data for: Voltamp Transformers Limited
# --- Processing File: Voltas_Limited.xlsx ---
#   Successfully extracted data for: Voltas Limited
# --- Processing File: VRL_LOGISTICS_LIMITED.xlsx ---
#   Successfully extracted data for: Vrl Logistics Limited
# --- Processing File: VST_INDUSTRIES_LIMITED.xlsx ---
#   Successfully extracted data for: Vst Industries Limited
# --- Processing File: WEBSOL_ENERGY_SYSTEM_LIMITED.xlsx ---
#   Successfully extracted data for: Websol Energy System Limited
# --- Processing File: Welspun_Corp_Limited.xlsx ---
#   Successfully extracted data for: Welspun Corp Limited
# --- Processing File: Welspun_Enterprises_Limited.xlsx ---
#   Successfully extracted data for: Welspun Enterprises Limited
# --- Processing File: Welspun_Living_Limited.xlsx ---
#   Successfully extracted data for: Welspun Living Limited
# --- Processing File: Wendt_(India)_Limited.xlsx ---
#   Successfully extracted data for: Wendt (India) Limited
# --- Processing File: Westlife_Foodworld_Limited.xlsx ---
#   Successfully extracted data for: Westlife Foodworld Limited
# --- Processing File: West_Coast_Paper_Mills_Limited.xlsx ---
#   Successfully extracted data for: West Coast Paper Mills Limited
# --- Processing File: Wheels_India_Limited.xlsx ---
#   Successfully extracted data for: Wheels India Limited
# --- Processing File: Whirlpool_of_India_Limited.xlsx ---
#   Successfully extracted data for: Whirlpool of India Limited
# --- Processing File: Wipro_Limited.xlsx ---
#   Successfully extracted data for: Wipro Limited
# --- Processing File: Wockhardt_Limited.xlsx ---
#   Successfully extracted data for: Wockhardt Limited
# --- Processing File: Wonderla_Holidays_Limited.xlsx ---
#   Successfully extracted data for: Wonderla Holidays Limited
# --- Processing File: Xchanging_Solutions_Limited.xlsx ---
#   Successfully extracted data for: Xchanging Solutions Limited
# --- Processing File: Xpro_India_Limited.xlsx ---
#   Successfully extracted data for: Xpro India Limited
# --- Processing File: Yasho_Industries_Limited.xlsx ---
#   Successfully extracted data for: Yasho Industries Limited
# --- Processing File: YATHARTH_HOSPITAL_&_TRAUMA_CARE_SERVICES_LIMITED.xlsx ---
#   Successfully extracted data for: Yatharth Hospital & Trauma Care Services Limited
# --- Processing File: Yatra_Online_Limited.xlsx ---
#   Successfully extracted data for: Yatra Online Limited
# --- Processing File: Yes_Bank_Limited.xlsx ---
#   Successfully extracted data for: Yes Bank Limited
# --- Processing File: Zaggle_Prepaid_Ocean_Services_Limited.xlsx ---
#   Successfully extracted data for: Zaggle Prepaid Ocean Services Limited
# --- Processing File: Zee_Entertainment_Enterprises_Limited.xlsx ---
#   Successfully extracted data for: Zee Entertainment Enterprises Limited
# --- Processing File: Zee_Media_Corporation_Limited.xlsx ---
#   Successfully extracted data for: Zee Media Corporation Limited
# --- Processing File: ZENSAR_TECHNOLOGIES_LIMITED.xlsx ---
#   Successfully extracted data for: Zensar Technologies Limited
# --- Processing File: Zen_Technologies_Limited.xlsx ---
#   Successfully extracted data for: Zen Technologies Limited
# --- Processing File: ZF_Commercial_Vehicle_Control_Systems_India_Limited.xlsx ---
#   Successfully extracted data for: ZF Commercial Vehicle Control Systems India Limited
# --- Processing File: Zomato_Limited.xlsx ---
#   Successfully extracted data for: Zomato Limited
# --- Processing File: ZOTA_HEALTH_CARE_LIMITED.xlsx ---
#   Successfully extracted data for: Zota Health Care Limited
# --- Processing File: Zydus_Lifesciences_Limited.xlsx ---
#   Successfully extracted data for: Zydus Lifesciences Limited
#   Extracted Phone: 18001206868
# --- Processing File: Zydus_Wellness_Limited.xlsx ---
#   Successfully extracted data for: Zydus Wellness Limited
#   Extracted Phone: 18001206868
#
# SUCCESS: Master Excel sheet 'p9_complaints.xlsx' has been created.
# Total companies processed: 1174
#
# --- SUMMARY STATISTICS (Top 5) ---
# In-Person / Branch Visit: 184 companies (15.7%)
# Postal Mail: 556 companies (47.4%)
# Written Correspondence: 164 companies (14.0%)
# Social Media: 599 companies (51.0%)
# Designated Grievance Officer / Nodal Team: 91 companies (7.8%)
# ...
#
# First few rows of the consolidated data:
#                     Company Name  In-Person / Branch Visit  Postal Mail  Written Correspondence  Social Media  \
# 0            360 One Wam Limited                         0            0                       0             1
# 1            3I Infotech Limited                         1            0                       0             1
# 2               3M India Limited                         1            1                       0             0
# 3         5paisa Capital Limited                         0            0                       0             1
# 4  63 Moons Technologies Limited                         0            0                       0             0
#
#    Designated Grievance Officer / Nodal Team  Website / Online Portal  Phone / Toll-Free Helpline  \
# 0                                        0                          1                           1
# 1                                        0                          1                           0
# 2                                        0                          1                           0
# 3                                        0                          1                           1
# 4                                        0                          1                           0
#
#    Email Communication  Mobile App  Chatbot / Live Chat  Ombudsman / Regulatory Body  Fax Extracted Phone Number  \
# 0                    1           0                    1                            1    0                   None
# 1                    1           1                    0                            0    0                   None
# 2                    1           1                    0                            0    0                   None
# 3                    1           0                    0                            0    0                   None
# 4                    1           0                    0                            0    0                   None
#
#          Consumer Complaint Mechanism Text
# 0  360 ONE is committed to provide its ...
# 1  At 3i Infotech, our commitment to co...
# 2  The entity has a comprehensive proce...
# 3  The mechanisms in place to receive a...
# 4  Customers may raise grievances throu...
