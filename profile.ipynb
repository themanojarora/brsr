# %% [markdown]
# ## Extracting Data from Excel files

# %% [markdown]
# ### Extracting Profile details for all the companies

# %%
import os
import pandas as pd
import glob

folder_path = "excel_files"

# Get a list of all .xlsx file paths
xlsx_files = glob.glob(os.path.join(folder_path, "*.xlsx"))

# %%
from tqdm import tqdm
import pandas as pd
import os

data_list = []

# List all .xlsx files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

for file_name in tqdm(excel_files, desc="Processing files", unit="file"):
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_excel(file_path)

    # Helper function to extract a single value or blank
    def get_value(element):
        values = df.loc[df['Element Name'] == element, 'Fact Value'].values
        return values[0] if len(values) > 0 else ''

    # Extract all required fields
    corporate_identity = get_value('CorporateIdentityNumber')
    company_name = get_value('NameOfTheCompany')
    date_of_incorporation = get_value('DateOfIncorporation')
    regd_office_address = get_value('AddressOfRegisteredOfficeOfCompany')
    corp_office_address = get_value('AddressOfCorporateOfficeOfCompany')
    company_email = get_value('EMailOfTheCompany')
    company_phone = get_value('TelephoneOfCompany')
    company_website = get_value('WebsiteOfCompany')
    paid_up_value = get_value('ValueOfSharesPaidUp')
    contact_name = get_value('NameOfContactPerson')
    contact_number = get_value('ContactNumberOfContactPerson')
    contact_email = get_value('EMailOfContactPerson')

    # Handle multiple exchange listings
    exchange_vals = df.loc[
        df['Element Name'] == 'NameOfStockExchangeWhereTheCompanyIsListed', 'Fact Value'
    ].dropna().unique().tolist()

    exchange_listed = ' and '.join(exchange_vals) if exchange_vals else ''

    # Append to data list
    data_list.append([
        corporate_identity, company_name, date_of_incorporation,
        regd_office_address, corp_office_address, company_email,
        company_phone, company_website, paid_up_value,
        contact_name, contact_number, contact_email, exchange_listed
    ])
# Out:
# Processing files: 100%|██████████████████████████████████████████████████████████| 1174/1174 [06:46<00:00,  2.88file/s]

# %%
 profile_df = pd.DataFrame(data_list, columns=[
    'CIN', 'Company', 'Incorporation Date',
    'Registered Address', 'Corporate Address',
    'Company Email', 'Company Telephone', 'Company Website',
    'Paid up share capital', 'Contact Person Name',
    'Contact Person Number', 'Contact Person Email',
    'Listed On'
]).sort_values(by='Company')

# %%
profile_df.shape
# Out:
# (1174, 14)

# %%
empty_counts = (profile_df.fillna('').applymap(str).applymap(str.strip) == '').sum() 
print(empty_counts) 
profile_df[profile_df.fillna('').applymap(str).applymap(str.strip).eq('').any(axis=1)]
# Out:
# CIN                       0
# Company                   0
# Incorporation Date       12
# Registered Address        0
# Corporate Address         5
# Company Email             0
# Company Telephone         0
# Company Website           0
# Paid up share capital     0
# Contact Person Name       0
# Contact Person Number     0
# Contact Person Email      0
# Listed On                 4
# company_lower             0
# dtype: int64
# C:\Users\manoj\AppData\Local\Temp\ipykernel_17888\1018157489.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   empty_counts = (profile_df.fillna('').applymap(str).applymap(str.strip) == '').sum()
# C:\Users\manoj\AppData\Local\Temp\ipykernel_17888\1018157489.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   profile_df[profile_df.fillna('').applymap(str).applymap(str.strip).eq('').any(axis=1)]
#                         CIN  \
# 10    L32202KA1949PLC032923
# 54    L45400HR1985PLC021622
# 272   L74899DL1995PLC065388
# 334   L24294PN1958PLC011052
# 369   L15500MH1981PLC025809
# 381   L15400GJ2009PLC058781
# 453   L74110UP2008PLC034977
# 461   L21011MH1950FLC145537
# 509   L99999GJ1976PLC018945
# 728   L92111DL1988PLC033099
# 881   L74899DL1993PLC053579
# 832   L26942TG1974PLC001693
# 898   L24239MH1956PLC009794
# 911   L29130PN1962PLC204515
# 917   L21012TZ1960PLC000364
# 929   L70109MH2021GOI371256
# 938   L63000MH1988PLC048500
# 979   L29222DL1979PLC009668
# 1075  L33121GJ1994PLC022460
# 1132  L26933WB1991PLC052968
# 1160  L74110MH1985PLC037900
#
#                                                 Company Incorporation Date  \
# 10                                    ABB India Limited
# 54                                    Anant Raj Limited         1985-07-30
# 272                           Dr. Lal Path Labs Limited         1995-02-14
# 334                                Foseco India Limited
# 369                                Gm Breweries Limited
# 381                                Gopal Snacks Limited         2009-12-07
# 453                         Hma Agro Industries Limited         2008-04-09
# 461                             Huhtamaki India Limited
# 509                                  Inox India Limited
# 728                        New Delhi Television Limited         1988-09-08
# 881                     R Systems International Limited
# 832                             Rain Industries Limited
# 898                                Sanofi India Limited
# 911                            Schaeffler India Limited
# 917                 Seshasayee Paper And Boards Limited
# 929   Shipping Corporation Of India Land And Assets ...         2021-11-10
# 938                Shreyas Shipping & Logistics Limited         1988-08-16
# 979                              Sterling Tools Limited         1979-06-07
# 1075        Transformers and Rectifiers (India) Limited
# 1132                             Vesuvius India Limited
# 1160                           Yasho Industries Limited         1985-10-30
#
#                                      Registered Address  \
# 10    “Disha”, Corporate Office, 3rd Floor, Plot No....
# 54    Plot No. CP-1, Sector-8 IMT Manesar, Gurugram-...
# 272        Block E, Sector-18, Rohini, New Delhi-110085
# 334   Foseco India Limited, Gat Nos. 922 and 923, Sa...
# 369   Ganesh Niwas Ground Floor, Veer Savarkar Marg,...
# 381   PLOT NO. G2322, G2323 & G2324, GIDC METODA TAL...
# 453   18A/5/3 TAJVIEW CROSSING FATEHABAD ROAD, Agra,...
# 461   A-802, Crescenzo, C-38/39, G Block, Bandra-Kur...
# 509   9TH FLOOR K P PLATINA RACE COURSE VADODARA 390007
# 728   W-17, 2nd Floor, Greater Kailash-I, New Delhi ...
# 881   GF-1-A, 6, Devika Tower, Nehru Place, Delhi – ...
# 832   RAIN CENTER, 34, SRINAGAR COLONY, HYDERABAD, T...
# 898   Sanofi House, CTS No. 117-B, L&T Business Park...
# 911   15th Floor, ASTP (Amar Sadanand Tech Park), Ba...
# 917   Pallipalayam, Namakkal District, Cauvery RS PO...
# 929   Shipping House, 245, Madame Cama Road, Nariman...
# 938   D-301 to 305, Level 3, Tower-II, Seawoods, Gra...
# 979   DJ-1210, 12th Floor, DLF Tower-B, Jasola Distr...
# 1075  Survey No. 427 P/3-4 & 431 P/1-2 Sarkhej Bavla...
# 1132         P-104,Taratala Road, Kolkata 700088, India
# 1160  Office No. 101/102 Peninsula Heights, CD Barfi...
#
#                                       Corporate Address  \
# 10    “Disha”, Corporate Office, 3rd Floor, Plot No....
# 1                                   Mrs. Varika Rastogi
# 2                              Ms. Smitha Gopalkrishnan
# 3                                        Namita Godbole
# 4                                       Hariraj Chouhan
# ...                                                 ...
# 1171                                   CS ASHVIN VARIYA
# 1172                                  Mr. Vishal J. Gor
# 1173                             Mr. Umesh V Parikh CFO
# 279                                 Srinivasan Nadadhur
# 468   Ms. Sonam Gupta - Company Secretary & Complian...
#
#             Contact Person Number            Contact Person Email    Listed On
# 0                 +91-22-48765600          sustainability@360.one  BSE and NSE
# 1                +91-22-7123 8000      compliance@3i-infotech.com  BSE and NSE
# 2                +91-80-2223 1414          sgopalkrishnan@mmm.com  BSE and NSE
# 3                    022 41035000               csteam@5paisa.com  NSE and BSE
# 4                     02266868010                info@63moons.com  BSE and NSE
# ...                           ...                             ...          ...
# 1171              +91 261 2331601       cszota@zotahealthcare.com          NSE
# 1172                +917948040235         vishalgor@zyduslife.com  BSE and NSE
# 1173  079-48040000, Ext. No. 1330  umesh.parikh@zyduswellness.com  BSE and NSE
# 279           +91 (022) 6614 8301                  esg@eclerx.com  BSE and NSE
# 468             91 (22) 6787 1000    compliance@ideaforgetech.com  BSE and NSE
#
# [1174 rows x 13 columns]

# %% [markdown]
# ### Data Cleaning
# From observation, we see that the names of companies are not in proper case in some instances. Also, the amil IDs and websites are also not propely in lowercase. The share capital is also stored as a string. Let's fix that.

# %%
profile_df['Company Email'] = profile_df['Company Email'].astype(str).str.lower()
profile_df['Contact Person Email'] = profile_df['Contact Person Email'].astype(str).str.lower()
profile_df['Company Website'] = profile_df['Company Website'].astype(str).str.lower()

import re

def clean_numeric(val):
    if pd.isna(val):
        return None
    val = str(val)
    val = re.sub(r'[^\d.]', '', val)  # remove everything except digits and dots
    return pd.to_numeric(val, errors='coerce')

profile_df['Paid up share capital'] = profile_df['Paid up share capital'].apply(clean_numeric)

# Now see what couldn't be converted
invalid_rows = profile_df[profile_df['Paid up share capital'].isna()]
if not invalid_rows.empty:
    print("\nStill invalid entries:")
    print(invalid_rows[['Company', 'Paid up share capital']])

# %%
profile_df.to_excel('profile.xlsx', index=False)

# %% [markdown]
# ### Add sectors
# We must add sector to the df because the analysis is sector-wise. Sectors for each of the companies are present in nse_data.xlsx that we extarcted earlier.

# %%
profile_df
# Out:
#                         CIN                        Company Incorporation Date  \
# 0     L74140MH2008PLC177884            360 One Wam Limited         2008-01-17
# 1     L67120MH1993PLC074411            3I Infotech Limited         1993-10-11
# 2     L31300KA1987PLC013543               3M India Limited         1987-07-04
# 3     L67190MH2007PLC289249         5paisa Capital Limited         2007-07-10
# 4     L29142TN1988PLC015586  63 Moons Technologies Limited         1988-04-12
# ...                     ...                            ...                ...
# 1171  L24231GJ2000PLC038352       Zota Health Care Limited         2000-07-12
# 1172  L24230GJ1995PLC025878     Zydus Lifesciences Limited         1995-05-15
# 1173  L15201GJ1994PLC023490         Zydus Wellness Limited         1994-11-01
# 279   L72200MH2000PLC125319        eClerx Services Limited         2000-03-24
# 468   U31401MH2007PLC167669   ideaForge Technology Limited         2007-02-08
#
#                                      Registered Address  \
# 0     360 ONE Centre, Kamala City, Senapati Bapat Ma...
# 1     Tower # 5, International Infotech Park, Vashi ...
# 2     Plot Nos. 48-51, Electronics City, Hosur Road,...
# 3     IIFL House, Sun Infotech Park, Road No. 16V, B...
# 4
# 0     BSE and NSE            360 one wam limited
# 1     BSE and NSE            3i infotech limited
# 2     BSE and NSE               3m india limited
# 3     NSE and BSE         5paisa capital limited
# 4     BSE and NSE  63 moons technologies limited
# ...           ...                            ...
# 1171          NSE       zota health care limited
# 1172  BSE and NSE     zydus lifesciences limited
# 1173  BSE and NSE         zydus wellness limited
# 279   BSE and NSE        eclerx services limited
# 468   BSE and NSE   ideaforge technology limited
#
# [1174 rows x 14 columns]

# %% [markdown]
# So, let's do this: Take in data from the nse_data.xlsx file which was downloaded from NSE website for BRSR. Then compare the names of companies and match them with the Symbol and add them to the profile_df.

# %%
nse_data = pd.read_excel('nse_data.xlsx')
nse_data
# Out:
#                                           Company      Symbol  FromYear  \
# 0                         Varun Beverages Limited         VBL      2024
# 1                           Castrol India Limited  CASTROLIND      2024
# 2                                  Cyient Limited      CYIENT      2023
# 3                                 Siemens Limited     SIEMENS      2023
# 4                        Indraprastha Gas Limited         IGL      2023
# ...                                           ...         ...       ...
# 1169                      Huhtamaki India Limited   HUHTAMAKI      2023
# 1170                         Sanofi India Limited      SANOFI      2023
# 1171  Transformers and Rectifiers (India) Limited       TARIL      2023
# 1172                      Rain Industries Limited        RAIN      2023
# 1173                            ABB India Limited         ABB      2023
#
#       ToYear                                             PDFURL  \
# 0       2024  https://nsearchives.nseindia.com/corporate/VBL...
# 1       2024  https://nsearchives.nseindia.com/corporate/CAS...
# 2       2024  https://nsearchives.nseindia.com/corporate/CYI...
# 3       2024  https://nsearchives.nseindia.com/corporate/SIE...
# 4       2024  https://nsearchives.nseindia.com/corporate/IGL...
# ...      ...                                                ...
# 1169    2023  https://nsearchives.nseindia.com/corporate/HUH...
# 1170    2023  https://nsearchives.nseindia.com/corporate/SAN...
# 1171    2024  https://nsearchives.nseindia.com/corporate/TRI...
# 1172    2023  https://nsearchives.nseindia.com/corporate/RAI...
# 1173    2023  https://nsearchives.nseindia.com/corporate/ABB...
#
#                                                 XBRLURL SubmissionDate  \
# 0     https://nsearchives.nseindia.com/corporate/xbr...     2025-03-11
# 1     https://nsearchives.nseindia.com/corporate/xbr...     2025-02-25
# 2     https://nsearchives.nseindia.com/corporate/xbr...     2025-02-19
# 3     https://nsearchives.nseindia.com/corporate/xbr...     2025-01-14
# 4     https://nsearchives.nseindia.com/corporate/xbr...     2024-12-17
# ...                                                 ...            ...
# 1169  https://nsearchives.nseindia.com/corporate/xbr...     2024-04-30
# 1170  https://nsearchives.nseindia.com/corporate/xbr...     2024-04-23
# 1171  https://nsearchives.nseindia.com/corporate/xbr...     2024-04-20
# 1172  https://nsearchives.nseindia.com/corporate/xbr...     2024-04-18
# 1173  https://nsearchives.nseindia.com/corporate/xbr...     2024-04-05
#
#                           Sector
# 0     Fast Moving Consumer Goods
# 1     Oil Gas & Consumable Fuels
# 2         Information Technology
# 3                  Capital Goods
# 4     Oil Gas & Consumable Fuels
# ...                          ...
# 1169               Capital Goods
# 1170                  Healthcare
# 1171               Capital Goods
# 1172                   Chemicals
# 1173               Capital Goods
#
# [1174 rows x 8 columns]

# %%
# Create helper columns with lowercase names
profile_df['company_lower'] = profile_df['Company'].str.lower().str.strip()
nse_data['company_lower'] = nse_data['Company'].str.lower().str.strip()

# Merge using lowercase names, but keep original casing from profile_df
merged_df = profile_df.merge(
    nse_data[['company_lower', 'Symbol']],
    on='company_lower',
    how='left'
)

# Display companies where Sector was not matched
unmatched = merged_df[merged_df['Symbol'].isna()]
if not unmatched.empty:
    print("\nCompanies with no matching sector:")
    print(unmatched[['Company']].drop_duplicates().sort_values('Company'))

# Drop helper column if no longer needed
merged_df.drop(columns=['company_lower'], inplace=True)
# Out:
# Companies with no matching sector:
#                                      Company
# 19                    Abans Holdings Limited
# 38                   Agro Tech Foods Limited
# 51               Allsec Technologies Limited
# 56                      Ami Organics Limited
# 199    Century Textiles & Industries Limited
# 299       Equinox India Developments Limited
# 366           Glenmark Life Sciences Limited
# 409                HBL Power Systems Limited
# 471                  IIFL Securities Limited
# 616            Lakshmi Machine Works Limited
# 941     Shreyas Shipping & Logistics Limited
# 1005             Suven Life Sciences Limited
# 1071  Tide Water Oil Company (India) Limited
# 1075                 Tips Industries Limited
# 1168                          Zomato Limited

# %%
merged_df
# Out:
#                         CIN                        Company Incorporation Date  \
# 0     L74140MH2008PLC177884            360 One Wam Limited         2008-01-17
# 1     L67120MH1993PLC074411            3I Infotech Limited         1993-10-11
# 2     L31300KA1987PLC013543               3M India Limited         1987-07-04
# 3     L67190MH2007PLC289249         5paisa Capital Limited         2007-07-10
# 4     L29142TN1988PLC015586  63 Moons Technologies Limited         1988-04-12
# ...                     ...                            ...                ...
# 1169  L24231GJ2000PLC038352       Zota Health Care Limited         2000-07-12
# 1170  L24230GJ1995PLC025878     Zydus Lifesciences Limited         1995-05-15
# 1171  L15201GJ1994PLC023490         Zydus Wellness Limited         1994-11-01
# 1172  L72200MH2000PLC125319        eClerx Services Limited         2000-03-24
# 1173  U31401MH2007PLC167669   ideaForge Technology Limited         2007-02-08
#
#                                      Registered Address  \
# 0     360 ONE Centre, Kamala City, Senapati Bapat Ma...
# 1     Tower # 5, International Infotech Park, Vashi ...
# 2     Plot Nos. 48-51, Electronics City, Hosur Road,...
# 3     IIFL House, Sun Infotech Park, Road No. 16V, B...
# 4     Shakti Tower -II, 4th Floor, Premises -J 766, ...
# ...                                                 ...
# 1169  ZOTA HOUSE 2/896 HIRA MODI STREET SAGRAMPURA S...
# 1170  "Zydus Corporate Park", Scheme No. 63, Survey ...
# 1171  Zydus Corporate Park, Scheme No. 63, Survey No...
# 1172  SONAWALA BUILDING, 1ST FLOOR, 29 BANK STREET F...
# 1173  EL-146, T.T.C. Industrial Area, M.I.D.C. Mahap...
#
#                                       Corporate Address  \
# 0     360 ONE Centre, Kamala City, Senapati Bapat Ma...
# 1     Tower 2, 6th Floor, E Wing, Seawoods Grand Cen...
# 2     WeWork Prestige Central, 3rd floor, 36 Infantr...
# 3     IIFL House, Sun Infotech Park, Road No. 16V, B...
# 4     FT Tower, CTS Nos.256 & 257, Suren Road, Andhe...
# ...                                                 ...
# 1169  ZOTA HOUSE, BHAGWAN AIYAPPA COMPLEX, NEXT TO B...
# 1170  "Zydus Corporate Park", Scheme No. 63, Survey ...
# 1171  Zydus Corporate Park, Scheme No. 63, Survey No...
# 1172  4th Floor, Express Towers, Nariman Point, Mumb...
# 1173  Unit 702, Q2 Bldg, Aurum Q Parc, Ghansoli, Nav...
#
#                              Company Email             Company Telephone  \
# 0                   sustainability@360.one               +91-22-48765600
# 1                investors@3i-infotech.com              +91-22-7123 8000
# 2              investorhelpdesk.in@mmm.com              +91-80-2223 1414
# 3                        csteam@5paisa.com                  022-41035000
# 4                         info@63moons.com                   02266868010
# ...                                    ...                           ...
# 1169               info@zotahealthcare.com               +91 261 2331601
# 1170              dhavalsoni@zyduslife.com  +917948040000, +917971800000
# 1171  investor.grievance@zyduswellness.com                  079-48040000
# 1172                   investor@eclerx.com           +91 (022) 6614 8301
# 1173          compliance@ideaforgetech.com                  022-67871000
#
#              Company Website  Paid up share capital  \
# 0                www.360.one           3.588626e+08
# 1        www.3i-infotech.com           1.692308e+08
# 2     https://www.3mindia.in           1.126507e+08
# 3             www.5paisa.com           3.119097e+08
# 4            www.63moons.com           9.215707e+07
# ...                      ...                    ...
# 1169  www.zotahealthcare.com           2.584733e+08
# 1170       www.zyduslife.com           1.006234e+09
# 1171   www.zyduswellness.com           6.363214e+08
# 1172          www.eclerx.com           4.902536e+08
# 1173   www.ideaforgetech.com           4.288532e+08
#
#                                     Contact Person Name  \
# 0     Mr. Rohit Bhase, Company Secretary & Complianc...
# 1                                   Mrs. Varika Rastogi
# 2                              Ms. Smitha Gopalkrishnan
# 3                                        Namita Godbole
# 4                                       Hariraj Chouhan
# ...                                                 ...
# 1169                                   CS ASHVIN VARIYA
# 1170                                  Mr. Vishal J. Gor
# 1171                             Mr. Umesh V Parikh CFO
# 1172                                Srinivasan Nadadhur
# 1173  Ms. Sonam Gupta - Company Secretary & Complian...
#
#             Contact Person Number            Contact Person Email  \
# 0                 +91-22-48765600          sustainability@360.one
# 1                +91-22-7123 8000      compliance@3i-infotech.com
# 2                +91-80-2223 1414          sgopalkrishnan@mmm.com
# 3                    022 41035000               csteam@5paisa.com
# 4                     02266868010                info@63moons.com
# ...                           ...                             ...
# 1169              +91 261 2331601       cszota@zotahealthcare.com
# 1170                +917948040235         vishalgor@zyduslife.com
# 1171  079-48040000, Ext. No. 1330  umesh.parikh@zyduswellness.com
# 1172          +91 (022) 6614 8301                  esg@eclerx.com
# 1173            91 (22) 6787 1000    compliance@ideaforgetech.com
#
#         Listed On     Symbol
# 0     BSE and NSE     360ONE
# 1     BSE and NSE  3IINFOLTD
# 2     BSE and NSE    3MINDIA
# 3     NSE and BSE     5PAISA
# 4     BSE and NSE    63MOONS
# ...           ...        ...
# 1169          NSE       ZOTA
# 1170  BSE and NSE  ZYDUSLIFE
# 1171  BSE and NSE  ZYDUSWELL
# 1172  BSE and NSE     ECLERX
# 1173  BSE and NSE  IDEAFORGE
#
# [1174 rows x 14 columns]

# %% [markdown]
# As it turns out,
#
# **Abans Holdings Limited** changed its name to **Abans Financial Services Limited** and its symbol was changed to **AFSL**.
#
# **Agro Tech Foods Limited** changed its name to **Sundrop Brands Limited** and its symbol changed from **ATFL** to **SUNDROP**.
#
# **Allsec Technologies Limited** changed its name to **Alldigi Tech Limited** and its symbol changed from **ALLSEC** to **ALLDIGI**.
#
# **Ami Organics Limited** is changing its name to **Acutaas Chemicals Limited**, and its symbol will change from **AMIORG** to **ACUTAAS**, effective **June 2, 2025**.
#
# **Century Textiles & Industries Limited** changed its name to **Aditya Birla Real Estate Limited** and its symbol was changed to **ABREL**.
#
# **Equinox India Developments Limited** changed its name to **Embassy Developments Limited** and its symbol changed from **EMBDL** to **EMBASSY**.
#
# **Glenmark Life Sciences Limited** changed its name to **Alivus Life Sciences Limited** and its symbol changed from **GLS** to **ALIVUS**, effective **January 20, 2025**.
#
# **HBL Power Systems Limited** changed its name to **HBL Engineering Limited** and its symbol changed from **HBLPOWER** to **HBLENGINE**, effective **December 23, 2024**.
#
# **IIFL Securities Limited** changed its name to **IIFL Capital Services Limited** and its symbol changed from **IIFLSEC** to **IIFLCAPS**, effective **December 3, 2024**.
#
# **Lakshmi Machine Works Limited** changed its name to **LMW Limited** and its symbol changed from **LAXMIMACH** to **LMW**, effective **October 10, 2024**.
#
# **Shreyas Shipping & Logistics Limited** changed its name to **Transworld Shipping Lines Limited** and its symbol changed from **SHREYAS** to **TRANSWORLD**, effective **October 23, 2024**.
#
# **Suven Life Sciences Limited** changed its name to **Cohance Lifesciences Limited** and its symbol changed from **SUVENPHAR** to **COHANCE**, effective **May 7, 2025**.
#
# **Tide Water Oil Company (India) Limited** changed its name to **Veedol Corporation Limited** and its symbol changed from **TWO** to **VEEDOL**, effective **October 9, 2024**.
#
# **Tips Industries Limited** changed its name to **Tips Music Limited** and its symbol changed from **TIPSINDLTD** to **TIPSMUSIC**, effective **September 30, 2024**.
#
# **Zomato Limited** changed its name to **Eternal Limited** and its symbol changed from **ZOMATO** to **ETERNAL**, effective **April 9, 2025**

# %%
merged_df.loc[merged_df["Company"] == "Abans Holdings Limited", "Symbol"] = "AFSL"
merged_df.loc[merged_df["Company"] == "Agro Tech Foods Limited", "Symbol"] = "SUNDROP"
merged_df.loc[merged_df["Company"] == "Allsec Technologies Limited", "Symbol"] = "ALLDIGI"
merged_df.loc[merged_df["Company"] == "Ami Organics Limited", "Symbol"] = "ACUTAAS"
merged_df.loc[merged_df["Company"] == "Century Textiles & Industries Limited", "Symbol"] = "ABREL"
merged_df.loc[merged_df["Company"] == "Equinox India Developments Limited", "Symbol"] = "EMBASSY"
merged_df.loc[merged_df["Company"] == "Glenmark Life Sciences Limited", "Symbol"] = "ALIVUS"
merged_df.loc[merged_df["Company"] == "HBL Power Systems Limited", "Symbol"] = "HBLENGINE"
merged_df.loc[merged_df["Company"] == "IIFL Securities Limited", "Symbol"] = "IIFLCAPS"
merged_df.loc[merged_df["Company"] == "Lakshmi Machine Works Limited", "Symbol"] = "LMW"
merged_df.loc[merged_df["Company"] == "Shreyas Shipping & Logistics Limited", "Symbol"] = "TRANSWORLD"
merged_df.loc[merged_df["Company"] == "Suven Life Sciences Limited", "Symbol"] = "COHANCE"
merged_df.loc[merged_df["Company"] == "Tide Water Oil Company (India) Limited", "Symbol"] = "VEEDOL"
merged_df.loc[merged_df["Company"] == "Tips Industries Limited", "Symbol"] = "TIPSMUSIC"
merged_df.loc[merged_df["Company"] == "Zomato Limited", "Symbol"] = "ETERNAL"

# %%
empty_counts = (merged_df.fillna('').applymap(str).applymap(str.strip) == '').sum() 
print(empty_counts) 
merged_df[merged_df.fillna('').applymap(str).applymap(str.strip).eq('').any(axis=1)]
# Out:
# CIN                       0
# Company                   0
# Incorporation Date       12
# Registered Address        0
# Corporate Address         5
# Company Email             0
# Company Telephone         0
# Company Website           0
# Paid up share capital     0
# Contact Person Name       0
# Contact Person Number     0
# Contact Person Email      0
# Listed On                 4
# Symbol                    0
# dtype: int64
# C:\Users\manoj\AppData\Local\Temp\ipykernel_17888\2805463571.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   empty_counts = (merged_df.fillna('').applymap(str).applymap(str.strip) == '').sum()
# C:\Users\manoj\AppData\Local\Temp\ipykernel_17888\2805463571.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   merged_df[merged_df.fillna('').applymap(str).applymap(str.strip).eq('').any(axis=1)]
#                         CIN  \
# 5     L32202KA1949PLC032923
# 59    L45400HR1985PLC021622
# 271   L74899DL1995PLC065388
# 333   L24294PN1958PLC011052
# 371   L15500MH1981PLC025809
# 383   L15400GJ2009PLC058781
# 453   L74110UP2008PLC034977
# 459   L21011MH1950FLC145537
# 513   L99999GJ1976PLC018945
# 730   L92111DL1988PLC033099
# 826   L74899DL1993PLC053579
# 837   L26942TG1974PLC001693
# 906   L24239MH1956PLC009794
# 915   L29130PN1962PLC204515
# 920   L21012TZ1960PLC000364
# 932   L70109MH2021GOI371256
# 941   L63000MH1988PLC048500
# 977   L29222DL1979PLC009668
# 1080  L33121GJ1994PLC022460
# 1130  L26933WB1991PLC052968
# 1158  L74110MH1985PLC037900
#
#                                                 Company Incorporation Date  \
# 5                                     ABB India Limited
# 59                                    Anant Raj Limited         1985-07-30
# 271                           Dr. Lal Path Labs Limited         1995-02-14
# 333                                Foseco India Limited
# 371                                Gm Breweries Limited
# 383                                Gopal Snacks Limited         2009-12-07
# 453                         Hma Agro Industries Limited         2008-04-09
# 459                             Huhtamaki India Limited
# 513                                  Inox India Limited
# 730                        New Delhi Television Limited         1988-09-08
# 826                     R Systems International Limited
# 837                             Rain Industries Limited
# 906                                Sanofi India Limited
# 915                            Schaeffler India Limited
# 920                 Seshasayee Paper And Boards Limited
# 932   Shipping Corporation Of India Land And Assets ...         2021-11-10
# 941                Shreyas Shipping & Logistics Limited         1988-08-16
# 977                              Sterling Tools Limited         1979-06-07
# 1080        Transformers and Rectifiers (India) Limited
# 1130                             Vesuvius India Limited
# 1158                           Yasho Industries Limited         1985-10-30
#
#                                      Registered Address  \
# 5     “Disha”, Corporate Office, 3rd Floor, Plot No....
# 59    Plot No. CP-1, Sector-8 IMT Manesar, Gurugram-...
# 271        Block E, Sector-18, Rohini, New Delhi-110085
# 333   Foseco India Limited, Gat Nos. 922 and 923, Sa...
# 371   Ganesh Niwas Ground Floor, Veer Savarkar Marg,...
# 383   PLOT NO. G2322, G2323 & G2324, GIDC METODA TAL...
# 453   18A/5/3 TAJVIEW CROSSING FATEHABAD ROAD, Agra,...
# 459   A-802, Crescenzo, C-38/39, G Block, Bandra-Kur...
# 513   9TH FLOOR K P PLATINA RACE COURSE VADODARA 390007
# 453                         cs@hmaagro.com  BSE and NSE     HMAAGRO
# 459           abhijaat.sinha@huhtamaki.com  NSE and BSE   HUHTAMAKI
# 513             deepak.acharya@inoxcva.com  BSE and NSE   INOXINDIA
# 730                   secretarial@ndtv.com  BSE and NSE        NDTV
# 826                      rsil@rsystems.com  BSE and NSE    RSYSTEMS
# 837        secretarial@rain-industries.com  BSE and NSE        RAIN
# 906                    igrc.sil@sanofi.com  BSE and NSE      SANOFI
# 915                alegocan@schaeffler.com  BSE and NSE  SCHAEFFLER
# 920                   srinivass@spbltd.com  BSE and NSE  SESHAPAPER
# 932                        dirpa@sci.co.in                   SCILAL
# 941         compliance.ssll@transworld.com               TRANSWORLD
# 977                  csec@stlfasteners.com                STERTOOLS
# 1080               cs@transformerindia.com  BSE and NSE       TARIL
# 1130         ashish.mukherjee@vesuvius.com  NSE and BSE    VESUVIUS
# 1158              info@yashoindustries.com  BSE and NSE       YASHO

# %% [markdown]
# ### Add Sector Details using Symbol

# %%
import requests
import time
import pandas as pd
from functools import lru_cache

class NSE:
    def __init__(self, verbose=True):
        self.verbose = verbose
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept-Language': 'en-US,en;q=0.9',
            'Cache-Control': 'max-age=0',
            'Referer': 'https://www.nseindia.com/',
            'Sec-Ch-Ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
            'Sec-Ch-Ua-Mobile': '?0',
            'Sec-Ch-Ua-Platform': '"Windows"',
            'Sec-Fetch-Dest': 'document',
            'Sec-Fetch-Mode': 'navigate',
            'Sec-Fetch-Site': 'same-origin',
            'Sec-Fetch-User': '?1',
            'Upgrade-Insecure-Requests': '1',
            'Connection': 'keep-alive'
        }
        self.session = self._create_session()
        self.initialize_session()

    def _log(self, message):
        if self.verbose:
            print(message)

    def _create_session(self):
        session = requests.Session()
        session.headers.update(self.headers)
        return session

    def initialize_session(self, specific_symbol=None):
        max_retries = 3
        retry_delay = 2

        for attempt in range(1, max_retries + 1):
            try:
                self._log(f"[{attempt}] Initializing NSE session")
                if attempt > 1:
                    self.session = self._create_session()

                response = self.session.get("https://www.nseindia.com/", timeout=10)
                response.raise_for_status()

                if not self.session.cookies:
                    self._log("No cookies received.")
                    time.sleep(retry_delay)
                    continue

                time.sleep(0.5)  # Small buffer

                if specific_symbol:
                    quote_url = f"https://www.nseindia.com/get-quotes/equity?symbol={specific_symbol.upper()}"
                    self.session.headers.update({'Referer': "https://www.nseindia.com/"})
                    quote_response = self.session.get(quote_url, timeout=10)
                    quote_response.raise_for_status()
                    time.sleep(0.5)

                return True

            except requests.RequestException as e:
                self._log(f"Session error: {e}")
                if attempt < max_retries:
                    time.sleep(retry_delay)
                    retry_delay *= 2
                else:
                    return False
        return False

    @lru_cache(maxsize=None)
    def get_sector_cached(self, symbol):
        return self._get_sector(symbol)

    def _get_sector(self, symbol):
        if not self.initialize_session(symbol):
            self._log(f"Retrying NSE session for {symbol}...")
            time.sleep(1)
            if not self.initialize_session(symbol):
                self._log("Final session retry failed.")
                return {}

        url = f"https://www.nseindia.com/api/quote-equity?symbol={symbol}"
        try:
            self.session.headers.update({'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={symbol}'})
            response = self.session.get(url, timeout=10)

            if response.status_code != 200:
                self._log(f"Retrying fetch for {symbol}, status {response.status_code}")
                if not self.initialize_session(symbol):
                    return {}
                time.sleep(1)
                response = self.session.get(url, timeout=10)

            if response.status_code == 200:
                data = response.json().get("industryInfo", [])
                return data
            else:
                self._log(f"Failed to fetch NSE data for {symbol} after retry.")
                return {}

        except Exception as e:
            self._log(f"Failed to parse data for {symbol}: {e}")
            return {}

# %%
x = nse.get_sector("RELIANCE")
# Out:
# Initializing/Refreshing NSE session (attempt 1/3)
# Error initializing NSE session (attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Retrying in 2 seconds...
# Initializing/Refreshing NSE session (attempt 2/3)
# Creating fresh session
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=RELIANCE
# Successfully accessed quote page for RELIANCE
# {'macro': 'Energy', 'sector': 'Oil Gas & Consumable Fuels', 'industry': 'Petroleum Products', 'basicIndustry': 'Refineries & Marketing'}

# %%
x = nse.get_sector("ITI")
# Out:
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ITI
# Successfully accessed quote page for ITI
# {'macro': 'Telecommunication', 'sector': 'Telecommunication', 'industry': 'Telecom - Equipment & Accessories', 'basicIndustry': 'Telecom - Equipment & Accessories'}

# %%
x = nse.get_sector("SBIN")
# Out:
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=SBIN
# Successfully accessed quote page for SBIN
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Public Sector Bank'}

# %% [markdown]
# So let's add all 4 of these to all the rows

# %%
merged_df = profile_df

# %%
# List to store missing company names
missing_companies = []

# Updated extractor with skip and log
def extract_sector_info_with_check(row):
    symbol = row["Symbol"]
    company = row["Company"]
    try:
        sector_data = nse.get_sector(symbol)
        if not sector_data:
            missing_companies.append(company)
            return pd.Series([None] * 4)
        return pd.Series([
            sector_data.get("macro", ""),
            sector_data.get("sector", ""),
            sector_data.get("industry", ""),
            sector_data.get("basicIndustry", "")
        ])
    except Exception:
        missing_companies.append(company)
        return pd.Series([None] * 4)

# Apply function
merged_df[["Macro Sector", "Sector", "Industry", "Basic Industry"]] = merged_df.apply(
    extract_sector_info_with_check, axis=1
)

# Print names of skipped companies
if missing_companies:
    print("Skipped the following companies due to missing sector information:")
    for company in missing_companies:
        print("-", company)
# Out:
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=360ONE
# Successfully accessed quote page for 360ONE
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Stockbroking & Allied'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=3IINFOLTD
# Successfully accessed quote page for 3IINFOLTD
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=3MINDIA
# Successfully accessed quote page for 3MINDIA
# {'macro': 'Diversified', 'sector': 'Diversified', 'industry': 'Diversified', 'basicIndustry': 'Diversified'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=5PAISA
# Successfully accessed quote page for 5PAISA
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Stockbroking & Allied'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=63MOONS
# Successfully accessed quote page for 63MOONS
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ABB
# Successfully accessed quote page for ABB
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Heavy Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACC
# Successfully accessed quote page for ACC
# {'macro': 'Commodities', 'sector': 'Construction Materials', 'industry': 'Cement & Cement Products', 'basicIndustry': 'Cement & Cement Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADFFOODS
# Successfully accessed quote page for ADFFOODS
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Food Products', 'basicIndustry': 'Packaged Foods'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AGI
# Successfully accessed quote page for AGI
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Packaging'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AIAENG
# Successfully accessed quote page for AIAENG
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Castings & Forgings'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APARINDS
# Successfully accessed quote page for APARINDS
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Other Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APLAPOLLO
# Successfully accessed quote page for APLAPOLLO
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Iron & Steel Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASKAUTOLTD
# Successfully accessed quote page for ASKAUTOLTD
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AUBANK
# Successfully accessed quote page for AUBANK
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Other Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AXISCADES
# Successfully accessed quote page for AXISCADES
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AARTIDRUGS
# Successfully accessed quote page for AARTIDRUGS
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AARTIIND
# Successfully accessed quote page for AARTIIND
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AARTIPHARM
# Successfully accessed quote page for AARTIPHARM
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AAVAS
# Successfully accessed quote page for AAVAS
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Housing Finance Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AFSL
# Successfully accessed quote page for AFSL
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Holding Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACCELYA
# Successfully accessed quote page for ACCELYA
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACE
# Successfully accessed quote page for ACE
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Agricultural Commercial & Construction Vehicles', 'basicIndustry': 'Construction Vehicles'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADANIENSOL
# Successfully accessed quote page for ADANIENSOL
# {'macro': 'Utilities', 'sector': 'Power', 'industry': 'Power', 'basicIndustry': 'Power Distribution'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADANIENT
# Successfully accessed quote page for ADANIENT
# {'macro': 'Commodities', 'sector': 'Metals & Mining', 'industry': 'Metals & Minerals Trading', 'basicIndustry': 'Trading - Minerals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADANIGREEN
# Successfully accessed quote page for ADANIGREEN
# {'macro': 'Utilities', 'sector': 'Power', 'industry': 'Power', 'basicIndustry': 'Power Generation'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADANIPORTS
# Successfully accessed quote page for ADANIPORTS
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Transport Infrastructure', 'basicIndustry': 'Port & Port services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADANIPOWER
# Successfully accessed quote page for ADANIPOWER
# {'macro': 'Utilities', 'sector': 'Power', 'industry': 'Power', 'basicIndustry': 'Integrated Power Utilities'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ATGL
# Successfully accessed quote page for ATGL
# {'macro': 'Energy', 'sector': 'Oil Gas & Consumable Fuels', 'industry': 'Gas', 'basicIndustry': 'LPG/CNG/PNG/LNG Supplier'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AWL
# Successfully accessed quote page for AWL
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Edible Oil'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ABCAPITAL
# Successfully accessed quote page for ABCAPITAL
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Investment Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ABFRL
# Successfully accessed quote page for ABFRL
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Retailing', 'basicIndustry': 'Speciality Retail'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ABSLAMC
# Successfully accessed quote page for ABSLAMC
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Asset Management Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADOR
# Successfully accessed quote page for ADOR
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Other Industrial Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ADVENZYMES
# Successfully accessed quote page for ADVENZYMES
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Biotechnology'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AEGISLOG
# Successfully accessed quote page for AEGISLOG
# {'macro': 'Energy', 'sector': 'Oil Gas & Consumable Fuels', 'industry': 'Gas', 'basicIndustry': 'Trading - Gas'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AETHER
# Successfully accessed quote page for AETHER
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AFFLE
# Successfully accessed quote page for AFFLE
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Services', 'basicIndustry': 'IT Enabled Services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AGARIND
# Successfully accessed quote page for AGARIND
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Petrochemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=SUNDROP
# Successfully accessed quote page for SUNDROP
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Edible Oil'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AGSTRA
# Successfully accessed quote page for AGSTRA
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Financial Technology (Fintech)', 'basicIndustry': 'Financial Technology (Fintech)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AHLUCONT
# Successfully accessed quote page for AHLUCONT
# {'macro': 'Industrials', 'sector': 'Construction', 'industry': 'Construction', 'basicIndustry': 'Civil Construction'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AJANTPHARM
# Successfully accessed quote page for AJANTPHARM
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AJMERA
# Successfully accessed quote page for AJMERA
# {'macro': 'Consumer Discretionary', 'sector': 'Realty', 'industry': 'Realty', 'basicIndustry': 'Residential Commercial Projects'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AKZOINDIA
# Successfully accessed quote page for AKZOINDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Paints'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALEMBICLTD
# Successfully accessed quote page for ALEMBICLTD
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Commercial Services & Supplies', 'basicIndustry': 'Diversified Commercial Services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APLLTD
# Successfully accessed quote page for APLLTD
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALICON
# Successfully accessed quote page for ALICON
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALKEM
# Successfully accessed quote page for ALKEM
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALKYLAMINE
# Successfully accessed quote page for ALKYLAMINE
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACLGATI
# Successfully accessed quote page for ACLGATI
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Transport Services', 'basicIndustry': 'Logistics Solution Provider'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALLCARGO
# Successfully accessed quote page for ALLCARGO
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Transport Services', 'basicIndustry': 'Logistics Solution Provider'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALLDIGI
# Successfully accessed quote page for ALLDIGI
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Commercial Services & Supplies', 'basicIndustry': 'Business Process Outsourcing (BPO)/ Knowledge Process Outsourcing (KPO)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ALOKINDS
# Successfully accessed quote page for ALOKINDS
# {'macro': 'Consumer Discretionary', 'sector': 'Textiles', 'industry': 'Textiles & Apparels', 'basicIndustry': 'Other Textile Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AMBER
# Successfully accessed quote page for AMBER
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Household Appliances'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AMBIKCO
# Successfully accessed quote page for AMBIKCO
# {'macro': 'Consumer Discretionary', 'sector': 'Textiles', 'industry': 'Textiles & Apparels', 'basicIndustry': 'Other Textile Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AMBUJACEM
# Successfully accessed quote page for AMBUJACEM
# {'macro': 'Commodities', 'sector': 'Construction Materials', 'industry': 'Cement & Cement Products', 'basicIndustry': 'Cement & Cement Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACUTAAS
# Successfully accessed quote page for ACUTAAS
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AMRUTANJAN
# Successfully accessed quote page for AMRUTANJAN
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ANANDRATHI
# Successfully accessed quote page for ANANDRATHI
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Financial Products Distributor'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ANANTRAJ
# Successfully accessed quote page for ANANTRAJ
# {'macro': 'Consumer Discretionary', 'sector': 'Realty', 'industry': 'Realty', 'basicIndustry': 'Residential Commercial Projects'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ANDHRAPAP
# Successfully accessed quote page for ANDHRAPAP
# {'macro': 'Commodities', 'sector': 'Forest Materials', 'industry': 'Paper Forest & Jute Products', 'basicIndustry': 'Paper & Paper Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ANGELONE
# Successfully accessed quote page for ANGELONE
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Stockbroking & Allied'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APCL
# Successfully accessed quote page for APCL
# {'macro': 'Commodities', 'sector': 'Construction Materials', 'industry': 'Cement & Cement Products', 'basicIndustry': 'Cement & Cement Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AWHCL
# Successfully accessed quote page for AWHCL
# {'macro': 'Utilities', 'sector': 'Utilities', 'industry': 'Other Utilities', 'basicIndustry': 'Waste Management'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ANURAS
# Successfully accessed quote page for ANURAS
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APCOTEXIND
# Successfully accessed quote page for APCOTEXIND
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Rubber'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=PARKHOTELS
# Successfully accessed quote page for PARKHOTELS
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Hotels & Resorts'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APEX
# Successfully accessed quote page for APEX
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Food Products', 'basicIndustry': 'Seafood'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APOLLOHOSP
# Successfully accessed quote page for APOLLOHOSP
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Healthcare Services', 'basicIndustry': 'Hospital'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APOLLO
# Successfully accessed quote page for APOLLO
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APOLLOPIPE
# Successfully accessed quote page for APOLLOPIPE
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Plastic Products - Industrial'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APOLLOTYRE
# Successfully accessed quote page for APOLLOTYRE
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Tyres & Rubber Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APTECHT
# Successfully accessed quote page for APTECHT
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Other Consumer Services', 'basicIndustry': 'Education'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=APTUS
# Successfully accessed quote page for APTUS
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Housing Finance Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ACI
# Successfully accessed quote page for ACI
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARIHANTCAP
# Successfully accessed quote page for ARIHANTCAP
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Stockbroking & Allied'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARMANFIN
# Successfully accessed quote page for ARMANFIN
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Non Banking Financial Company (NBFC)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARTEMISMED
# Successfully accessed quote page for ARTEMISMED
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Healthcare Services', 'basicIndustry': 'Hospital'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARVINDFASN
# Successfully accessed quote page for ARVINDFASN
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Retailing', 'basicIndustry': 'Speciality Retail'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARVIND
# Successfully accessed quote page for ARVIND
# {'macro': 'Consumer Discretionary', 'sector': 'Textiles', 'industry': 'Textiles & Apparels', 'basicIndustry': 'Garments & Apparels'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ARVSMART
# Successfully accessed quote page for ARVSMART
# {'macro': 'Consumer Discretionary', 'sector': 'Realty', 'industry': 'Realty', 'basicIndustry': 'Residential Commercial Projects'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASAHIINDIA
# Successfully accessed quote page for ASAHIINDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASHAPURMIN
# Successfully accessed quote page for ASHAPURMIN
# {'macro': 'Commodities', 'sector': 'Metals & Mining', 'industry': 'Minerals & Mining', 'basicIndustry': 'Industrial Minerals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASHIANA
# Successfully accessed quote page for ASHIANA
# {'macro': 'Consumer Discretionary', 'sector': 'Realty', 'industry': 'Realty', 'basicIndustry': 'Residential Commercial Projects'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASHOKLEY
# Successfully accessed quote page for ASHOKLEY
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Agricultural Commercial & Construction Vehicles', 'basicIndustry': 'Commercial Vehicles'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASHOKA
# Successfully accessed quote page for ASHOKA
# {'macro': 'Industrials', 'sector': 'Construction', 'industry': 'Construction', 'basicIndustry': 'Civil Construction'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASIANPAINT
# Successfully accessed quote page for ASIANPAINT
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Paints'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASTEC
# Successfully accessed quote page for ASTEC
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Fertilizers & Agrochemicals', 'basicIndustry': 'Pesticides & Agrochemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASTERDM
# Successfully accessed quote page for ASTERDM
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Healthcare Services', 'basicIndustry': 'Hospital'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASTRAMICRO
# Successfully accessed quote page for ASTRAMICRO
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASTRAZEN
# Successfully accessed quote page for ASTRAZEN
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASTRAL
# Successfully accessed quote page for ASTRAL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Plastic Products - Industrial'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ATUL
# Successfully accessed quote page for ATUL
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AURIONPRO
# Successfully accessed quote page for AURIONPRO
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AUROPHARMA
# Successfully accessed quote page for AUROPHARMA
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AIIL
# Successfully accessed quote page for AIIL
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Non Banking Financial Company (NBFC)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AUTOIND
# Successfully accessed quote page for AUTOIND
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AUTOAXLES
# Successfully accessed quote page for AUTOAXLES
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ASAL
# Successfully accessed quote page for ASAL
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AVADHSUGAR
# Successfully accessed quote page for AVADHSUGAR
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Sugar'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AVALON
# Successfully accessed quote page for AVALON
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Other Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AVANTIFEED
# Successfully accessed quote page for AVANTIFEED
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Food Products', 'basicIndustry': 'Animal Feed'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=DMART
# Successfully accessed quote page for DMART
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Retailing', 'basicIndustry': 'Diversified Retail'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AVTNPL
# Successfully accessed quote page for AVTNPL
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Other Agricultural Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AXISBANK
# Successfully accessed quote page for AXISBANK
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Private Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=AZAD
# Successfully accessed quote page for AZAD
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Heavy Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BASF
# Successfully accessed quote page for BASF
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BEML
# Successfully accessed quote page for BEML
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Agricultural Commercial & Construction Vehicles', 'basicIndustry': 'Construction Vehicles'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BLS
# Successfully accessed quote page for BLS
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Tour Travel Related Services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BSE
# Successfully accessed quote page for BSE
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Capital Markets', 'basicIndustry': 'Exchange and Data Platform'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJ-AUTO
# Successfully accessed quote page for BAJAJ-AUTO
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Automobiles', 'basicIndustry': '2/3 Wheelers'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJCON
# Successfully accessed quote page for BAJAJCON
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Personal Products', 'basicIndustry': 'Personal Care'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJELEC
# Successfully accessed quote page for BAJAJELEC
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Household Appliances'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE
# Successfully accessed quote page for BAJFINANCE
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Non Banking Financial Company (NBFC)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJFINSV
# Successfully accessed quote page for BAJAJFINSV
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Holding Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJHCARE
# Successfully accessed quote page for BAJAJHCARE
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJHIND
# Successfully accessed quote page for BAJAJHIND
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Sugar'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJAJHLDNG
# Successfully accessed quote page for BAJAJHLDNG
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Holding Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BAJEL
# Successfully accessed quote page for BAJEL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Heavy Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALAMINES
# Successfully accessed quote page for BALAMINES
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALAXI
# Successfully accessed quote page for BALAXI
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALKRISIND
# Successfully accessed quote page for BALKRISIND
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Tyres & Rubber Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALMLAWRIE
# Successfully accessed quote page for BALMLAWRIE
# {'macro': 'Diversified', 'sector': 'Diversified', 'industry': 'Diversified', 'basicIndustry': 'Diversified'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALRAMCHIN
# Successfully accessed quote page for BALRAMCHIN
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Sugar'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BALUFORGE
# Successfully accessed quote page for BALUFORGE
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Castings & Forgings'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANARBEADS
# Successfully accessed quote page for BANARBEADS
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Gems Jewellery And Watches'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANCOINDIA
# Successfully accessed quote page for BANCOINDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANDHANBNK
# Successfully accessed quote page for BANDHANBNK
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Private Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANKINDIA
# Successfully accessed quote page for BANKINDIA
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Public Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=MAHABANK
# Successfully accessed quote page for MAHABANK
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Public Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANKBARODA
# Successfully accessed quote page for BANKBARODA
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Public Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BANARISUG
# Successfully accessed quote page for BANARISUG
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Agricultural Food & other Products', 'basicIndustry': 'Sugar'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BARBEQUE
# Successfully accessed quote page for BARBEQUE
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Restaurants'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BATAINDIA
# Successfully accessed quote page for BATAINDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Footwear'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BCLIND
# Successfully accessed quote page for BCLIND
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Beverages', 'basicIndustry': 'Breweries & Distilleries'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BERGEPAINT
# Successfully accessed quote page for BERGEPAINT
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Paints'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BESTAGRO
# Error initializing NSE session (attempt 1): HTTPSConnectionPool(host='www.nseindia.com', port=443): Read timed out. (read timeout=15)
# Retrying in 2 seconds...
# Initializing/Refreshing NSE session (attempt 2/3)
# Creating fresh session
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BESTAGRO
# Successfully accessed quote page for BESTAGRO
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Fertilizers & Agrochemicals', 'basicIndustry': 'Pesticides & Agrochemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BFINVEST
# Successfully accessed quote page for BFINVEST
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Finance', 'basicIndustry': 'Holding Company'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BFUTILITIE
# Successfully accessed quote page for BFUTILITIE
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Transport Infrastructure', 'basicIndustry': 'Road Assets - Toll Annuity Hybrid-Annuity'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHAGERIA
# Successfully accessed quote page for BHAGERIA
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Dyes And Pigments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHAGCHEM
# Successfully accessed quote page for BHAGCHEM
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Fertilizers & Agrochemicals', 'basicIndustry': 'Pesticides & Agrochemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BEPL
# Successfully accessed quote page for BEPL
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BBL
# Successfully accessed quote page for BBL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Other Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BDL
# Successfully accessed quote page for BDL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BEL
# Successfully accessed quote page for BEL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHARATFORG
# Successfully accessed quote page for BHARATFORG
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHEL
# Successfully accessed quote page for BHEL
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Heavy Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BPCL
# Successfully accessed quote page for BPCL
# {'macro': 'Energy', 'sector': 'Oil Gas & Consumable Fuels', 'industry': 'Petroleum Products', 'basicIndustry': 'Refineries & Marketing'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHARATRAS
# Successfully accessed quote page for BHARATRAS
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Fertilizers & Agrochemicals', 'basicIndustry': 'Pesticides & Agrochemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHARATWIRE
# Successfully accessed quote page for BHARATWIRE
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Iron & Steel Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHARTIARTL
# Successfully accessed quote page for BHARTIARTL
# {'macro': 'Telecommunication', 'sector': 'Telecommunication', 'industry': 'Telecom - Services', 'basicIndustry': 'Telecom - Cellular & Fixed line services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BHARTIHEXA
# Successfully accessed quote page for BHARTIHEXA
# {'macro': 'Telecommunication', 'sector': 'Telecommunication', 'industry': 'Telecom - Services', 'basicIndustry': 'Telecom - Cellular & Fixed line services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=BIGBLOC
# Successfully accessed quote page for BIGBLOC
# ...
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VBL
# Successfully accessed quote page for VBL
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Beverages', 'basicIndustry': 'Other Beverages'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=MANYAVAR
# Successfully accessed quote page for MANYAVAR
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Retailing', 'basicIndustry': 'Speciality Retail'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VEDL
# Successfully accessed quote page for VEDL
# {'macro': 'Commodities', 'sector': 'Metals & Mining', 'industry': 'Diversified Metals', 'basicIndustry': 'Diversified Metals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VENKEYS
# Successfully accessed quote page for VENKEYS
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Food Products', 'basicIndustry': 'Meat Products including Poultry'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VENUSPIPES
# Successfully accessed quote page for VENUSPIPES
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Iron & Steel Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VERANDA
# Successfully accessed quote page for VERANDA
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Other Consumer Services', 'basicIndustry': 'E-Learning'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VESUVIUS
# Successfully accessed quote page for VESUVIUS
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Electrodes & Refractories'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VIDHIING
# Successfully accessed quote page for VIDHIING
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VIJAYA
# Successfully accessed quote page for VIJAYA
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Healthcare Services', 'basicIndustry': 'Healthcare Service Provider'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VINATIORGA
# Successfully accessed quote page for VINATIORGA
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VINDHYATEL
# Successfully accessed quote page for VINDHYATEL
# {'macro': 'Telecommunication', 'sector': 'Telecommunication', 'industry': 'Telecom - Services', 'basicIndustry': 'Telecom - Infrastructure'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VIPIND
# Successfully accessed quote page for VIPIND
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Plastic Products - Consumer'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VISAKAIND
# Successfully accessed quote page for VISAKAIND
# {'macro': 'Commodities', 'sector': 'Construction Materials', 'industry': 'Cement & Cement Products', 'basicIndustry': 'Cement & Cement Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VISHNU
# Successfully accessed quote page for VISHNU
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VPRPL
# Successfully accessed quote page for VPRPL
# {'macro': 'Industrials', 'sector': 'Construction', 'industry': 'Construction', 'basicIndustry': 'Civil Construction'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=IDEA
# Successfully accessed quote page for IDEA
# {'macro': 'Telecommunication', 'sector': 'Telecommunication', 'industry': 'Telecom - Services', 'basicIndustry': 'Telecom - Cellular & Fixed line services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VOLTAMP
# Successfully accessed quote page for VOLTAMP
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Heavy Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VOLTAS
# Successfully accessed quote page for VOLTAS
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Household Appliances'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VRLLOG
# Successfully accessed quote page for VRLLOG
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Transport Services', 'basicIndustry': 'Logistics Solution Provider'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=VSTIND
# Successfully accessed quote page for VSTIND
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Cigarettes & Tobacco Products', 'basicIndustry': 'Cigarettes & Tobacco Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WEBELSOLAR
# Successfully accessed quote page for WEBELSOLAR
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Electrical Equipment', 'basicIndustry': 'Other Electrical Equipment'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WELCORP
# Successfully accessed quote page for WELCORP
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Iron & Steel Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WELENT
# Successfully accessed quote page for WELENT
# {'macro': 'Industrials', 'sector': 'Construction', 'industry': 'Construction', 'basicIndustry': 'Civil Construction'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WELSPUNLIV
# Successfully accessed quote page for WELSPUNLIV
# {'macro': 'Consumer Discretionary', 'sector': 'Textiles', 'industry': 'Textiles & Apparels', 'basicIndustry': 'Other Textile Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WENDT
# Successfully accessed quote page for WENDT
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Abrasives & Bearings'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WSTCSTPAPR
# Successfully accessed quote page for WSTCSTPAPR
# {'macro': 'Commodities', 'sector': 'Forest Materials', 'industry': 'Paper Forest & Jute Products', 'basicIndustry': 'Paper & Paper Products'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WESTLIFE
# Successfully accessed quote page for WESTLIFE
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Restaurants'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WHEELS
# Successfully accessed quote page for WHEELS
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WHIRLPOOL
# Successfully accessed quote page for WHIRLPOOL
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Durables', 'industry': 'Consumer Durables', 'basicIndustry': 'Household Appliances'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WIPRO
# Successfully accessed quote page for WIPRO
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WOCKPHARMA
# Successfully accessed quote page for WOCKPHARMA
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=WONDERLA
# Successfully accessed quote page for WONDERLA
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Amusement Parks/ Other Recreation'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=XCHANGING
# Successfully accessed quote page for XCHANGING
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=XPROINDIA
# Successfully accessed quote page for XPROINDIA
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Industrial Products', 'basicIndustry': 'Packaging'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=YASHO
# Successfully accessed quote page for YASHO
# {'macro': 'Commodities', 'sector': 'Chemicals', 'industry': 'Chemicals & Petrochemicals', 'basicIndustry': 'Specialty Chemicals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=YATHARTH
# Successfully accessed quote page for YATHARTH
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Healthcare Services', 'basicIndustry': 'Hospital'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=YATRA
# Successfully accessed quote page for YATRA
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Leisure Services', 'basicIndustry': 'Tour Travel Related Services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=YESBANK
# Successfully accessed quote page for YESBANK
# {'macro': 'Financial Services', 'sector': 'Financial Services', 'industry': 'Banks', 'basicIndustry': 'Private Sector Bank'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZFCVINDIA
# Successfully accessed quote page for ZFCVINDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Automobile and Auto Components', 'industry': 'Auto Components', 'basicIndustry': 'Auto Components & Equipments'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZAGGLE
# Successfully accessed quote page for ZAGGLE
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Services', 'basicIndustry': 'IT Enabled Services'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZEEL
# Successfully accessed quote page for ZEEL
# {'macro': 'Consumer Discretionary', 'sector': 'Media Entertainment & Publication', 'industry': 'Entertainment', 'basicIndustry': 'TV Broadcasting & Software Production'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZEEMEDIA
# Successfully accessed quote page for ZEEMEDIA
# {'macro': 'Consumer Discretionary', 'sector': 'Media Entertainment & Publication', 'industry': 'Entertainment', 'basicIndustry': 'TV Broadcasting & Software Production'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZENTEC
# Successfully accessed quote page for ZENTEC
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZENSARTECH
# Successfully accessed quote page for ZENSARTECH
# {'macro': 'Information Technology', 'sector': 'Information Technology', 'industry': 'IT - Software', 'basicIndustry': 'Computers - Software & Consulting'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ETERNAL
# Successfully accessed quote page for ETERNAL
# {'macro': 'Consumer Discretionary', 'sector': 'Consumer Services', 'industry': 'Retailing', 'basicIndustry': 'E-Retail/ E-Commerce'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZOTA
# Successfully accessed quote page for ZOTA
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZYDUSLIFE
# Successfully accessed quote page for ZYDUSLIFE
# {'macro': 'Healthcare', 'sector': 'Healthcare', 'industry': 'Pharmaceuticals & Biotechnology', 'basicIndustry': 'Pharmaceuticals'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ZYDUSWELL
# Successfully accessed quote page for ZYDUSWELL
# {'macro': 'Fast Moving Consumer Goods', 'sector': 'Fast Moving Consumer Goods', 'industry': 'Food Products', 'basicIndustry': 'Packaged Foods'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=ECLERX
# Successfully accessed quote page for ECLERX
# {'macro': 'Services', 'sector': 'Services', 'industry': 'Commercial Services & Supplies', 'basicIndustry': 'Business Process Outsourcing (BPO)/ Knowledge Process Outsourcing (KPO)'}
# Initializing/Refreshing NSE session (attempt 1/3)
# Accessing quote page: https://www.nseindia.com/get-quotes/equity?symbol=IDEAFORGE
# Successfully accessed quote page for IDEAFORGE
# {'macro': 'Industrials', 'sector': 'Capital Goods', 'industry': 'Aerospace & Defense', 'basicIndustry': 'Aerospace & Defense'}
# Skipped the following companies due to missing sector information:
# - Suven Pharmaceuticals Limited
# - The Jammu & Kashmir Bank Limited

# %%
merged_df
# Out:
#                         CIN                        Company Incorporation Date  \
# 0     L74140MH2008PLC177884            360 One Wam Limited         2008-01-17
# 1     L67120MH1993PLC074411            3I Infotech Limited         1993-10-11
# 2     L31300KA1987PLC013543               3M India Limited         1987-07-04
# 3     L67190MH2007PLC289249         5paisa Capital Limited         2007-07-10
# 4     L29142TN1988PLC015586  63 Moons Technologies Limited         1988-04-12
# ...                     ...                            ...                ...
# 1169  L24231GJ2000PLC038352       Zota Health Care Limited         2000-07-12
# 1170  L24230GJ1995PLC025878     Zydus Lifesciences Limited         1995-05-15
# 1171  L15201GJ1994PLC023490         Zydus Wellness Limited         1994-11-01
# 1172  L72200MH2000PLC125319        eClerx Services Limited         2000-03-24
# 1173  U31401MH2007PLC167669   ideaForge Technology Limited         2007-02-08
#
#                                      Registered Address  \
# 0     360 ONE Centre, Kamala City, Senapati Bapat Ma...
# 1     Tower # 5, International Infotech Park, Vashi ...
# 2     Plot Nos. 48-51, Electronics City, Hosur Road,...
# 3     IIFL House, Sun Infotech Park, Road No. 16V, B...
# 4     Shakti Tower -II, 4th Floor, Premises -J 766, ...
# ...                                                 ...
# 1169  ZOTA HOUSE 2/896 HIRA MODI STREET SAGRAMPURA S...
# 1170  "Zydus Corporate Park", Scheme No. 63, Survey ...
# 1171  Zydus Corporate Park, Scheme No. 63, Survey No...
# 1172  SONAWALA BUILDING, 1ST FLOOR, 29 BANK STREET F...
# 1173  EL-146, T.T.C. Industrial Area, M.I.D.C. Mahap...
#
#                                       Corporate Address  \
# 0     360 ONE Centre, Kamala City, Senapati Bapat Ma...
# 1     Tower 2, 6th Floor, E Wing, Seawoods Grand Cen...
# 2     WeWork Prestige Central, 3rd floor, 36 Infantr...
# 3     IIFL House, Sun Infotech Park, Road No. 16V, B...
# 4     FT Tower, CTS Nos.256 & 257, Suren Road, Andhe...
# ...                                                 ...
# 1169  ZOTA HOUSE, BHAGWAN AIYAPPA COMPLEX, NEXT TO B...
# 1170  "Zydus Corporate Park", Scheme No. 63, Survey ...
# 1171  Zydus Corporate Park, Scheme No. 63, Survey No...
# 1172  4th Floor, Express Towers, Nariman Point, Mumb...
# 1173  Unit 702, Q2 Bldg, Aurum Q Parc, Ghansoli, Nav...
#
#                              Company Email             Company Telephone  \
# 0                   sustainability@360.one               +91-22-48765600
# 1                investors@3i-infotech.com              +91-22-7123 8000
# 2              investorhelpdesk.in@mmm.com              +91-80-2223 1414
# 3                        csteam@5paisa.com                  022-41035000
# 4                         info@63moons.com                   02266868010
# ...                                    ...                           ...
# 1169               info@zotahealthcare.com               +91 261 2331601
# 1170              dhavalsoni@zyduslife.com  +917948040000, +917971800000
# 1171  investor.grievance@zyduswellness.com                  079-48040000
# 1172                   investor@eclerx.com           +91 (022) 6614 8301
# 1173          compliance@ideaforgetech.com                  022-67871000
#
#              Company Website  Paid up share capital  \
# 0                www.360.one           3.588626e+08
# 1        www.3i-infotech.com           1.692308e+08
# 2     https://www.3mindia.in           1.126507e+08
# 3             www.5paisa.com           3.119097e+08
# 4            www.63moons.com           9.215707e+07
# ...                      ...                    ...
# 1169  www.zotahealthcare.com           2.584733e+08
# 1170       www.zyduslife.com           1.006234e+09
# 1171   www.zyduswellness.com           6.363214e+08
# 1172          www.eclerx.com           4.902536e+08
# 1173   www.ideaforgetech.com           4.288532e+08
#
#                                     Contact Person Name  \
# 0     Mr. Rohit Bhase, Company Secretary & Complianc...
# 1                                   Mrs. Varika Rastogi
# 2                              Ms. Smitha Gopalkrishnan
# 3                                        Namita Godbole
# 4                                       Hariraj Chouhan
# ...                                                 ...
# 1169                                   CS ASHVIN VARIYA
# 1170                                  Mr. Vishal J. Gor
# 1171                             Mr. Umesh V Parikh CFO
# 1172                                Srinivasan Nadadhur
# 1173  Ms. Sonam Gupta - Company Secretary & Complian...
#
#             Contact Person Number            Contact Person Email  \
# 0                 +91-22-48765600          sustainability@360.one
# 1                +91-22-7123 8000      compliance@3i-infotech.com
# 2                +91-80-2223 1414          sgopalkrishnan@mmm.com
# 3                    022 41035000               csteam@5paisa.com
# 4                     02266868010                info@63moons.com
# ...                           ...                             ...
# 1169              +91 261 2331601       cszota@zotahealthcare.com
# 1170                +917948040235         vishalgor@zyduslife.com
# 1171  079-48040000, Ext. No. 1330  umesh.parikh@zyduswellness.com
# 1172          +91 (022) 6614 8301                  esg@eclerx.com
# 1173            91 (22) 6787 1000    compliance@ideaforgetech.com
#
#         Listed On     Symbol                Macro Sector  \
# 0     BSE and NSE     360ONE          Financial Services
# 1     BSE and NSE  3IINFOLTD      Information Technology
# 2     BSE and NSE    3MINDIA                 Diversified
# 3     NSE and BSE     5PAISA          Financial Services
# 4     BSE and NSE    63MOONS      Information Technology
# ...           ...        ...                         ...
# 1169          NSE       ZOTA                  Healthcare
# 1170  BSE and NSE  ZYDUSLIFE                  Healthcare
# 1171  BSE and NSE  ZYDUSWELL  Fast Moving Consumer Goods
# 1172  BSE and NSE     ECLERX                    Services
# 1173  BSE and NSE  IDEAFORGE                 Industrials
#
#                           Sector                         Industry  \
# 0             Financial Services                  Capital Markets
# 1         Information Technology                    IT - Software
# 2                    Diversified                      Diversified
# 3             Financial Services                  Capital Markets
# 4         Information Technology                    IT - Software
# ...                          ...                              ...
# 1169                  Healthcare  Pharmaceuticals & Biotechnology
# 1170                  Healthcare  Pharmaceuticals & Biotechnology
# 1171  Fast Moving Consumer Goods                    Food Products
# 1172                    Services   Commercial Services & Supplies
# 1173               Capital Goods              Aerospace & Defense
#
#                                          Basic Industry
# 0                                 Stockbroking & Allied
# 1                     Computers - Software & Consulting
# 2                                           Diversified
# 3                                 Stockbroking & Allied
# 4                     Computers - Software & Consulting
# ...                                                 ...
# 1169                                    Pharmaceuticals
# 1170                                    Pharmaceuticals
# 1171                                     Packaged Foods
# 1172  Business Process Outsourcing (BPO)/ Knowledge ...
# 1173                                Aerospace & Defense
#
# [1174 rows x 18 columns]

# %%
merged_df.to_excel('final_profile.xlsx', index=False)

# %%
# The remaining errors I fixed manually.
